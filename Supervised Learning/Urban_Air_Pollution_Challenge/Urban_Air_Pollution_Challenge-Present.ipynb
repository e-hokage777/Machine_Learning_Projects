# %% [markdown]
# # Urban Air Pollution Challenge
# Prediction the concentration of PM25 in the air

# %% [markdown]
# ## Model Pipeline
# - ### Exploratory Data Analysis
#   - Checked for columns with null values (more than 80% of features had null values)
#   - About 8 features had more than 80% of their values missing
#   - Checked correlation of those features to target to see if they were worth filling up
#   - None of those features were correlated with the target variable
#   - Looked for features that had a relatively high correlation to target variable
#   - Plotted the distributions to get a sense of the kind of filling to do
#   - Filled fairly normal features with mean since skew could be caused by outlier
#   - Filled skewed features with median since outilers don't affect median
#
#  - ### Feature Engineering
#    - Made some features that were too skewed more normally distributed
#    - Looked for combinations of features with high correlation to target
#
# ## Methodology
# - Scaled to the data using standard scaling
# - Used grid search with a 5-fold split, with `root mean squared error` as the scoring metric criteria to explore different hyperparameter combinations for models
#
# Below is table showing the best scores for each model:
# <table>
#     <tr>
#         <th>Model name</th>
#         <th>Score</th>
#     </tr>
#     <tr>
#         <td>Linear Regression</td>
#         <td>38.032</td>
#     </tr>
#     <tr>
#         <td>Support Vector Regressor</td>
#         <td>36.521</td>
#     </tr>
#     <tr>
#         <td>Decision Tree Regressor</td>
#         <td>36.723</td>
#     </tr>
#     <tr>
#         <td>LGBMRegessor</td>
#         <td>28.174</td>
#     </tr>
# </table>
#
# Highest Publice Leader Mean Squared Error: ***34.397***
# <br>
# Rank: ***100***

# %%
## importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## reading necessary data
data_loc = "x__data/"
df_train = pd.read_csv(f"{data_loc}/train.csv")
df_test = pd.read_csv(f"{data_loc}/test.csv")

# %%
## taking a look at the training data
df_train.head()
# Out:
#         Place_ID X Date        Date Place_ID  target  target_min  target_max  \
# 0  010Q650 X 2020-01-02  2020-01-02  010Q650    38.0        23.0        53.0
# 1  010Q650 X 2020-01-03  2020-01-03  010Q650    39.0        25.0        63.0
# 2  010Q650 X 2020-01-04  2020-01-04  010Q650    24.0         8.0        56.0
# 3  010Q650 X 2020-01-05  2020-01-05  010Q650    49.0        10.0        55.0
# 4  010Q650 X 2020-01-06  2020-01-06  010Q650    21.0         9.0        52.0
#
#    target_variance  target_count  precipitable_water_entire_atmosphere  \
# 0           769.50            92                             11.000000
# 1          1319.85            91                             14.600000
# 2          1181.96            96                             16.400000
# 3          1113.67            96                              6.911948
# 4          1164.82            95                             13.900001
#
#    relative_humidity_2m_above_ground  ...  L3_SO2_sensor_zenith_angle  \
# 0                          60.200001  ...                   38.593017
# 1                          48.799999  ...                   59.624912
# 2                          33.400002  ...                   49.839714
# 3                          21.300001  ...                   29.181258
# 4                          44.700001  ...                    0.797294
#
#    L3_SO2_solar_azimuth_angle  L3_SO2_solar_zenith_angle  \
# 0                  -61.752587                  22.363665
# 1                  -67.693509                  28.614804
# 2                  -78.342701                  34.296977
# 3                  -73.896588                  30.545446
# 4                  -68.612480                  26.899694
#
#    L3_CH4_CH4_column_volume_mixing_ratio_dry_air  L3_CH4_aerosol_height  \
# 0                                    1793.793579            3227.855469
# 1                                    1789.960449            3384.226562
# 2                                            NaN                    NaN
# 3                                            NaN                    NaN
# 4                                            NaN                    NaN
#
#    L3_CH4_aerosol_optical_depth  L3_CH4_sensor_azimuth_angle  \
# 0                      0.010579                    74.481049
# 1                      0.015104                    75.630043
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
#
#    L3_CH4_sensor_zenith_angle  L3_CH4_solar_azimuth_angle  \
# 0                   37.501499                  -62.142639
# 1                   55.657486                  -53.868134
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    L3_CH4_solar_zenith_angle
# 0                  22.545118
# 1                  19.293652
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
# [5 rows x 82 columns]

# %%
## taking a look at the testing data
df_test.head()
# Out:
#         Place_ID X Date        Date Place_ID  \
# 0  0OS9LVX X 2020-01-02  2020-01-02  0OS9LVX
# 1  0OS9LVX X 2020-01-03  2020-01-03  0OS9LVX
# 2  0OS9LVX X 2020-01-04  2020-01-04  0OS9LVX
# 3  0OS9LVX X 2020-01-05  2020-01-05  0OS9LVX
# 4  0OS9LVX X 2020-01-06  2020-01-06  0OS9LVX
#
#    precipitable_water_entire_atmosphere  relative_humidity_2m_above_ground  \
# 0                             11.600000                          30.200001
# 1                             18.300001                          42.900002
# 2                             17.600000                          41.299999
# 3                             15.011948                          53.100002
# 4                              9.700000                          71.599998
#
#    specific_humidity_2m_above_ground  temperature_2m_above_ground  \
# 0                            0.00409                    14.656824
# 1                            0.00595                    15.026544
# 2                            0.00590                    15.511041
# 3                            0.00709                    14.441858
# 4                            0.00808                    11.896295
#
#    u_component_of_wind_10m_above_ground  v_component_of_wind_10m_above_ground  \
# 0                              3.956377                              0.712605
# 1                              4.230430                              0.661892
# 2                              5.245728                              1.640559
# 3                              5.454001                             -0.190532
# 4                              3.511787                             -0.279441
#
#    L3_NO2_NO2_column_number_density  ...  L3_SO2_sensor_zenith_angle  \
# 0                          0.000053  ...                    1.445658
# 1                          0.000050  ...                   34.641758
# 2                          0.000050  ...                   55.872276
# 3                          0.000055  ...                   59.174188
# 4                          0.000055  ...                   40.925873
#
#    L3_SO2_solar_azimuth_angle  L3_SO2_solar_zenith_angle  \
# 0                  -95.984984                  22.942019
# 1                  -95.014908                  18.539116
# 2                  -94.015418                  14.140820
# 3                  -97.247602                  32.730553
# 4                  -96.057265                  28.320527
#
#    L3_CH4_CH4_column_volume_mixing_ratio_dry_air  L3_CH4_aerosol_height  \
# 0                                            NaN                    NaN
# 1                                            NaN                    NaN
# 2                                            NaN                    NaN
# 3                                            NaN                    NaN
# 4                                    1831.261597            3229.118652
#
#    L3_CH4_aerosol_optical_depth  L3_CH4_sensor_azimuth_angle  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                      0.031068                  -100.278343
#
#    L3_CH4_sensor_zenith_angle  L3_CH4_solar_azimuth_angle  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                    41.84708                  -95.910744
#
#    L3_CH4_solar_zenith_angle
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                  28.498789
#
# [5 rows x 77 columns]

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (30557, 82)
# (16136, 77)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ####  Checking features with nulls

# %%
(df_train.isna().sum().sort_values(ascending=False)/df_train.shape[0])[:60]
# Out:
# L3_CH4_solar_zenith_angle                              0.810453
# L3_CH4_solar_azimuth_angle                             0.810453
# L3_CH4_sensor_zenith_angle                             0.810453
# L3_CH4_sensor_azimuth_angle                            0.810453
# L3_CH4_aerosol_optical_depth                           0.810453
# L3_CH4_aerosol_height                                  0.810453
# L3_CH4_CH4_column_volume_mixing_ratio_dry_air          0.810453
# L3_NO2_tropospheric_NO2_column_number_density          0.283699
# L3_HCHO_tropospheric_HCHO_column_number_density_amf    0.242989
# L3_HCHO_tropospheric_HCHO_column_number_density        0.242989
# L3_HCHO_solar_zenith_angle                             0.242989
# L3_HCHO_solar_azimuth_angle                            0.242989
# L3_HCHO_sensor_zenith_angle                            0.242989
# L3_HCHO_sensor_azimuth_angle                           0.242989
# L3_HCHO_cloud_fraction                                 0.242989
# L3_HCHO_HCHO_slant_column_number_density               0.242989
# L3_SO2_absorbing_aerosol_index                         0.239160
# L3_SO2_SO2_slant_column_number_density                 0.236836
# L3_SO2_solar_zenith_angle                              0.236836
# L3_SO2_SO2_column_number_density_amf                   0.236836
# L3_SO2_cloud_fraction                                  0.236836
# L3_SO2_sensor_azimuth_angle                            0.236836
# L3_SO2_solar_azimuth_angle                             0.236836
# L3_SO2_sensor_zenith_angle                             0.236836
# L3_SO2_SO2_column_number_density                       0.236836
# L3_CO_solar_zenith_angle                               0.177472
# L3_CO_CO_column_number_density                         0.177472
# L3_CO_H2O_column_number_density                        0.177472
# L3_CO_cloud_height                                     0.177472
# L3_CO_sensor_altitude                                  0.177472
# L3_CO_sensor_azimuth_angle                             0.177472
# L3_CO_sensor_zenith_angle                              0.177472
# L3_CO_solar_azimuth_angle                              0.177472
# L3_NO2_tropopause_pressure                             0.071669
# L3_NO2_stratospheric_NO2_column_number_density         0.071669
# L3_NO2_solar_zenith_angle                              0.071669
# L3_NO2_solar_azimuth_angle                             0.071669
# L3_NO2_sensor_zenith_angle                             0.071669
# L3_NO2_sensor_azimuth_angle                            0.071669
# L3_NO2_NO2_column_number_density                       0.071637
# L3_NO2_absorbing_aerosol_index                         0.071637
# L3_NO2_cloud_fraction                                  0.071637
# L3_NO2_NO2_slant_column_number_density                 0.071637
# L3_NO2_sensor_altitude                                 0.071637
# L3_CLOUD_surface_albedo                                0.049809
# L3_CLOUD_cloud_top_pressure                            0.049809
# L3_CLOUD_cloud_top_height                              0.049809
# L3_CLOUD_cloud_optical_depth                           0.049809
# L3_CLOUD_cloud_base_pressure                           0.049809
# L3_CLOUD_cloud_base_height                             0.049809
# L3_CLOUD_sensor_azimuth_angle                          0.012239
# L3_CLOUD_sensor_zenith_angle                           0.012239
# L3_CLOUD_solar_azimuth_angle                           0.012239
# L3_CLOUD_solar_zenith_angle                            0.012239
# L3_CLOUD_cloud_fraction                                0.012239
# L3_O3_O3_column_number_density                         0.009261
# L3_O3_O3_effective_temperature                         0.009261
# L3_O3_cloud_fraction                                   0.009261
# L3_O3_sensor_azimuth_angle                             0.009261
# L3_O3_sensor_zenith_angle                              0.009261
# dtype: float64

# %% [markdown]
# #### Over 80% of features have null values

# %%
(df_train.isna().sum() > 0).sum()/df_train.shape[1]
# Out:
# 0.8292682926829268

# %%
## removing columns from training data
cols_to_rem = [
    'L3_CH4_solar_zenith_angle',
    'L3_CH4_solar_azimuth_angle',
    'L3_CH4_sensor_zenith_angle',
    'L3_CH4_sensor_azimuth_angle',
    'L3_CH4_aerosol_optical_depth',
    'L3_CH4_aerosol_height',
    'L3_CH4_CH4_column_volume_mixing_ratio_dry_air'         
]

# temp_train = df_train.drop(cols_to_rem, axis=1)

# %%
## getting the columns in the training data that are not in the testing data
train_cols = set(df_train.columns)
test_cols = set(df_test.columns)

diff_cols = list(train_cols - test_cols)

# %% [markdown]
# #### Checking correlation of features with over 80% of missing values with target variables
# As can be seen from the results below, those features are not at all correlated with the target

# %%
### checking whether any of the columns to remove has a high correlation with target
df_train[cols_to_rem + diff_cols].corr()["target"].sort_values()
# Out:
# L3_CH4_solar_azimuth_angle                      -0.118004
# L3_CH4_sensor_azimuth_angle                      0.012264
# L3_CH4_sensor_zenith_angle                       0.031025
# L3_CH4_solar_zenith_angle                        0.043264
# L3_CH4_aerosol_height                            0.073632
# L3_CH4_CH4_column_volume_mixing_ratio_dry_air    0.075086
# L3_CH4_aerosol_optical_depth                     0.086445
# target_count                                     0.094135
# target_variance                                  0.184818
# target_max                                       0.630801
# target_min                                       0.818803
# target                                           1.000000
# Name: target, dtype: float64

# %%
fig = plt.figure(figsize=(10,10))
sns.heatmap(df_train[cols_to_rem + diff_cols].corr(), annot=True, fmt=".2f")
plt.show()

# %% [markdown]
# #### Checking correlation of other features to target

# %%
## checking correlation of other columns to target
df_train.select_dtypes("number").corr()["target"].sort_values(ascending=False)[:40]
# Out:
# target                                             1.000000
# target_min                                         0.818803
# target_max                                         0.630801
# L3_CO_CO_column_number_density                     0.375737
# L3_HCHO_tropospheric_HCHO_column_number_density    0.347125
# L3_HCHO_HCHO_slant_column_number_density           0.320849
# L3_NO2_NO2_slant_column_number_density             0.315718
# L3_NO2_NO2_column_number_density                   0.306772
# L3_NO2_tropospheric_NO2_column_number_density      0.295380
# target_variance                                    0.184818
# L3_SO2_absorbing_aerosol_index                     0.152000
# L3_CLOUD_cloud_top_pressure                        0.123855
# L3_CLOUD_cloud_base_pressure                       0.097343
# target_count                                       0.094135
# L3_CH4_aerosol_optical_depth                       0.086445
# L3_CH4_CH4_column_volume_mixing_ratio_dry_air      0.075086
# L3_CH4_aerosol_height                              0.073632
# L3_AER_AI_absorbing_aerosol_index                  0.070795
# L3_SO2_SO2_slant_column_number_density             0.059665
# L3_NO2_sensor_altitude                             0.057273
# L3_SO2_SO2_column_number_density                   0.045052
# L3_CH4_solar_zenith_angle                          0.043264
# L3_NO2_sensor_zenith_angle                         0.037475
# L3_NO2_stratospheric_NO2_column_number_density     0.035819
# L3_O3_O3_effective_temperature                     0.034375
# L3_CH4_sensor_zenith_angle                         0.031025
# L3_NO2_absorbing_aerosol_index                     0.030386
# L3_SO2_sensor_azimuth_angle                        0.016728
# L3_HCHO_sensor_azimuth_angle                       0.013455
# L3_O3_sensor_zenith_angle                          0.012354
# L3_CH4_sensor_azimuth_angle                        0.012264
# L3_CO_sensor_zenith_angle                          0.011007
# L3_CO_sensor_azimuth_angle                         0.009023
# L3_HCHO_sensor_zenith_angle                        0.008498
# L3_CLOUD_sensor_zenith_angle                       0.007673
# L3_SO2_sensor_zenith_angle                         0.007332
# L3_CO_sensor_altitude                              0.006389
# L3_AER_AI_sensor_azimuth_angle                     0.006084
# L3_AER_AI_sensor_zenith_angle                      0.004524
# L3_CLOUD_sensor_azimuth_angle                      0.003763
# Name: target, dtype: float64

# %%
df_train.select_dtypes("number").corr()["target"].sort_values(ascending=False)[40:]
# Out:
# L3_NO2_sensor_azimuth_angle                            0.003722
# L3_O3_sensor_azimuth_angle                             0.001783
# L3_NO2_solar_zenith_angle                              0.001192
# L3_CO_H2O_column_number_density                       -0.000596
# L3_HCHO_cloud_fraction                                -0.011736
# L3_SO2_SO2_column_number_density_amf                  -0.016116
# L3_SO2_cloud_fraction                                 -0.025099
# precipitable_water_entire_atmosphere                  -0.031329
# specific_humidity_2m_above_ground                     -0.035670
# L3_SO2_solar_zenith_angle                             -0.037803
# temperature_2m_above_ground                           -0.038818
# L3_HCHO_solar_zenith_angle                            -0.038851
# L3_CO_solar_zenith_angle                              -0.049490
# L3_CLOUD_surface_albedo                               -0.053733
# v_component_of_wind_10m_above_ground                  -0.055100
# L3_O3_solar_zenith_angle                              -0.055617
# L3_CLOUD_solar_zenith_angle                           -0.072071
# L3_AER_AI_solar_zenith_angle                          -0.082660
# L3_NO2_tropopause_pressure                            -0.084550
# relative_humidity_2m_above_ground                     -0.084835
# L3_CLOUD_cloud_base_height                            -0.087670
# L3_O3_O3_column_number_density                        -0.088099
# L3_CO_cloud_height                                    -0.106133
# L3_CLOUD_cloud_top_height                             -0.106536
# L3_O3_cloud_fraction                                  -0.108538
# L3_CLOUD_cloud_fraction                               -0.113222
# L3_HCHO_tropospheric_HCHO_column_number_density_amf   -0.114348
# L3_CH4_solar_azimuth_angle                            -0.118004
# L3_CLOUD_cloud_optical_depth                          -0.118504
# L3_NO2_cloud_fraction                                 -0.123956
# u_component_of_wind_10m_above_ground                  -0.148202
# L3_CO_solar_azimuth_angle                             -0.159954
# L3_NO2_solar_azimuth_angle                            -0.177861
# L3_SO2_solar_azimuth_angle                            -0.180241
# L3_HCHO_solar_azimuth_angle                           -0.181548
# L3_O3_solar_azimuth_angle                             -0.185363
# L3_CLOUD_solar_azimuth_angle                          -0.187643
# L3_AER_AI_solar_azimuth_angle                         -0.193434
# L3_AER_AI_sensor_altitude                             -0.308308
# Name: target, dtype: float64

# %%
df_train.isna().sum()[:40]
# Out:
# Place_ID X Date                                      0
# Date                                                 0
# Place_ID                                             0
# target                                               0
# target_min                                           0
# target_max                                           0
# target_variance                                      0
# target_count                                         0
# precipitable_water_entire_atmosphere                 0
# relative_humidity_2m_above_ground                    0
# specific_humidity_2m_above_ground                    0
# temperature_2m_above_ground                          0
# u_component_of_wind_10m_above_ground                 0
# v_component_of_wind_10m_above_ground                 0
# L3_NO2_NO2_column_number_density                  2189
# L3_NO2_NO2_slant_column_number_density            2189
# L3_NO2_absorbing_aerosol_index                    2189
# L3_NO2_cloud_fraction                             2189
# L3_NO2_sensor_altitude                            2189
# L3_NO2_sensor_azimuth_angle                       2190
# L3_NO2_sensor_zenith_angle                        2190
# L3_NO2_solar_azimuth_angle                        2190
# L3_NO2_solar_zenith_angle                         2190
# L3_NO2_stratospheric_NO2_column_number_density    2190
# L3_NO2_tropopause_pressure                        2190
# L3_NO2_tropospheric_NO2_column_number_density     8669
# L3_O3_O3_column_number_density                     283
# L3_O3_O3_effective_temperature                     283
# L3_O3_cloud_fraction                               283
# L3_O3_sensor_azimuth_angle                         283
# L3_O3_sensor_zenith_angle                          283
# L3_O3_solar_azimuth_angle                          283
# L3_O3_solar_zenith_angle                           283
# L3_CO_CO_column_number_density                    5423
# L3_CO_H2O_column_number_density                   5423
# L3_CO_cloud_height                                5423
# L3_CO_sensor_altitude                             5423
# L3_CO_sensor_azimuth_angle                        5423
# L3_CO_sensor_zenith_angle                         5423
# L3_CO_solar_azimuth_angle                         5423
# dtype: int64

# %% [markdown]
# ### Insights
# - remove features with more than `80%` missing values
# - `none` of the columns with more than `80%` missing values has high correlation with target

# %% [markdown]
# #### Getting the features that have relatively high correlation to target

# %%
## getting n_largest features correlated with target

l = []

for col in df_train.select_dtypes("number").corr()["target"].sort_values(ascending=False)[1:12].index:
    if not col.startswith("target"):
        l.append(col)

# %%
df_train[l].isna().sum()
# Out:
# L3_CO_CO_column_number_density                     5423
# L3_HCHO_tropospheric_HCHO_column_number_density    7425
# L3_HCHO_HCHO_slant_column_number_density           7425
# L3_NO2_NO2_slant_column_number_density             2189
# L3_NO2_NO2_column_number_density                   2189
# L3_NO2_tropospheric_NO2_column_number_density      8669
# L3_SO2_absorbing_aerosol_index                     7308
# L3_CLOUD_cloud_top_pressure                        1522
# dtype: int64

# %% [markdown]
# #### Displaying distributions of said features

# %%
### plotting distributions for targets
fig, axes = plt.subplots(4,2, figsize=(12,12))
for ax, col in zip(axes.flatten(),l):
    sns.histplot(df_train[col], ax=ax, kde=True)


plt.tight_layout()
plt.show()

# %%
df_train[l].describe().loc["mean",:]
# Out:
# L3_CO_CO_column_number_density                         0.036230
# L3_HCHO_tropospheric_HCHO_column_number_density        0.000088
# L3_HCHO_HCHO_slant_column_number_density               0.000043
# L3_NO2_NO2_slant_column_number_density                 0.000163
# L3_NO2_NO2_column_number_density                       0.000094
# L3_NO2_tropospheric_NO2_column_number_density          0.000056
# L3_SO2_absorbing_aerosol_index                        -1.944519
# L3_CLOUD_cloud_top_pressure                        70799.498221
# Name: mean, dtype: float64

# %%
df_train[l].median()
# Out:
# L3_CO_CO_column_number_density                         0.035563
# L3_HCHO_tropospheric_HCHO_column_number_density        0.000076
# L3_HCHO_HCHO_slant_column_number_density               0.000037
# L3_NO2_NO2_slant_column_number_density                 0.000150
# L3_NO2_NO2_column_number_density                       0.000075
# L3_NO2_tropospheric_NO2_column_number_density          0.000035
# L3_SO2_absorbing_aerosol_index                        -1.963547
# L3_CLOUD_cloud_top_pressure                        74094.354412
# dtype: float64

# %%
df_train[l].skew().sort_values()
# Out:
# L3_CLOUD_cloud_top_pressure                       -0.534658
# L3_HCHO_HCHO_slant_column_number_density           0.410458
# L3_SO2_absorbing_aerosol_index                     0.510803
# L3_HCHO_tropospheric_HCHO_column_number_density    0.905838
# L3_CO_CO_column_number_density                     1.274629
# L3_NO2_NO2_slant_column_number_density             4.109591
# L3_NO2_tropospheric_NO2_column_number_density      6.185637
# L3_NO2_NO2_column_number_density                   7.402073
# dtype: float64

# %%
## looking into the negative correlated features
r = []

for col in df_train.select_dtypes("number").corr()["target"].sort_values(ascending=False)[-17:].index:
    if not col.startswith("target"):
        r.append(col)

# %%
df_train[r].isna().sum()
# Out:
# L3_CO_cloud_height                                      5423
# L3_CLOUD_cloud_top_height                               1522
# L3_O3_cloud_fraction                                     283
# L3_CLOUD_cloud_fraction                                  374
# L3_HCHO_tropospheric_HCHO_column_number_density_amf     7425
# L3_CH4_solar_azimuth_angle                             24765
# L3_CLOUD_cloud_optical_depth                            1522
# L3_NO2_cloud_fraction                                   2189
# u_component_of_wind_10m_above_ground                       0
# L3_CO_solar_azimuth_angle                               5423
# L3_NO2_solar_azimuth_angle                              2190
# L3_SO2_solar_azimuth_angle                              7237
# L3_HCHO_solar_azimuth_angle                             7425
# L3_O3_solar_azimuth_angle                                283
# L3_CLOUD_solar_azimuth_angle                             374
# L3_AER_AI_solar_azimuth_angle                            197
# L3_AER_AI_sensor_altitude                                197
# dtype: int64

# %%
df_train[r].skew().sort_values()
# Out:
# L3_CH4_solar_azimuth_angle                             0.061542
# L3_CLOUD_cloud_fraction                                0.384587
# u_component_of_wind_10m_above_ground                   0.387020
# L3_O3_cloud_fraction                                   0.413894
# L3_HCHO_tropospheric_HCHO_column_number_density_amf    0.786242
# L3_CO_cloud_height                                     0.811320
# L3_NO2_cloud_fraction                                  0.960893
# L3_CLOUD_cloud_top_height                              1.130542
# L3_AER_AI_solar_azimuth_angle                          1.154523
# L3_O3_solar_azimuth_angle                              1.156257
# L3_NO2_solar_azimuth_angle                             1.156622
# L3_AER_AI_sensor_altitude                              1.241691
# L3_CLOUD_solar_azimuth_angle                           1.272288
# L3_HCHO_solar_azimuth_angle                            2.002888
# L3_SO2_solar_azimuth_angle                             2.074658
# L3_CO_solar_azimuth_angle                              2.117308
# L3_CLOUD_cloud_optical_depth                           3.346628
# dtype: float64

# %%
r[4:]
# Out:
# ['L3_HCHO_tropospheric_HCHO_column_number_density_amf',
#  'L3_CH4_solar_azimuth_angle',
#  'L3_CLOUD_cloud_optical_depth',
#  'L3_NO2_cloud_fraction',
#  'u_component_of_wind_10m_above_ground',
#  'L3_CO_solar_azimuth_angle',
#  'L3_NO2_solar_azimuth_angle',
#  'L3_SO2_solar_azimuth_angle',
#  'L3_HCHO_solar_azimuth_angle',
#  'L3_O3_solar_azimuth_angle',
#  'L3_CLOUD_solar_azimuth_angle',
#  'L3_AER_AI_solar_azimuth_angle',
#  'L3_AER_AI_sensor_altitude']

# %% [markdown]
# #### Observing the skew of different features to determine how to fix them

# %%
### fixing skew
skew_fix_cols = ["L3_HCHO_tropospheric_HCHO_column_number_density",
                    "L3_CO_CO_column_number_density",
                    "L3_NO2_NO2_slant_column_number_density",
                    "L3_NO2_tropospheric_NO2_column_number_density",
                    "L3_NO2_NO2_column_number_density",
                    'L3_HCHO_tropospheric_HCHO_column_number_density_amf',
                    'L3_CH4_solar_azimuth_angle',
                     'L3_CLOUD_cloud_optical_depth',
                     'L3_CO_solar_azimuth_angle',
                     'L3_NO2_solar_azimuth_angle',
                     'L3_SO2_solar_azimuth_angle',
                     'L3_HCHO_solar_azimuth_angle',
                     'L3_O3_solar_azimuth_angle',
                     'L3_CLOUD_solar_azimuth_angle',
                     'L3_AER_AI_solar_azimuth_angle',
                     'L3_AER_AI_sensor_altitude',
                     "L3_NO2_cloud_fraction"
                   ]

df_train[skew_fix_cols].skew()
# Out:
# L3_HCHO_tropospheric_HCHO_column_number_density        0.905838
# L3_CO_CO_column_number_density                         1.274629
# L3_NO2_NO2_slant_column_number_density                 4.109591
# L3_NO2_tropospheric_NO2_column_number_density          6.185637
# L3_NO2_NO2_column_number_density                       7.402073
# L3_HCHO_tropospheric_HCHO_column_number_density_amf    0.786242
# L3_CH4_solar_azimuth_angle                             0.061542
# L3_CLOUD_cloud_optical_depth                           3.346628
# L3_CO_solar_azimuth_angle                              2.117308
# L3_NO2_solar_azimuth_angle                             1.156622
# L3_SO2_solar_azimuth_angle                             2.074658
# L3_HCHO_solar_azimuth_angle                            2.002888
# L3_O3_solar_azimuth_angle                              1.156257
# L3_CLOUD_solar_azimuth_angle                           1.272288
# L3_AER_AI_solar_azimuth_angle                          1.154523
# L3_AER_AI_sensor_altitude                              1.241691
# L3_NO2_cloud_fraction                                  0.960893
# dtype: float64

# %%
np.sqrt(df_train[skew_fix_cols]).skew().sort_values()
# Out:
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\blocks.py:366: RuntimeWarning: invalid value encountered in sqrt
#   result = func(self.values, **kwargs)
# L3_CO_CO_column_number_density                        -1.917712
# L3_HCHO_tropospheric_HCHO_column_number_density_amf   -1.446148
# L3_NO2_NO2_slant_column_number_density                -0.685811
# L3_HCHO_tropospheric_HCHO_column_number_density        0.216977
# L3_NO2_cloud_fraction                                  0.278943
# L3_NO2_NO2_column_number_density                       0.563960
# L3_CO_solar_azimuth_angle                              0.580558
# L3_SO2_solar_azimuth_angle                             0.889750
# L3_NO2_tropospheric_NO2_column_number_density          0.988802
# L3_HCHO_solar_azimuth_angle                            1.002784
# L3_AER_AI_sensor_altitude                              1.235687
# L3_CLOUD_cloud_optical_depth                           1.766666
# L3_NO2_solar_azimuth_angle                             2.145496
# L3_O3_solar_azimuth_angle                              2.339333
# L3_CLOUD_solar_azimuth_angle                           3.586603
# L3_AER_AI_solar_azimuth_angle                          4.124028
# L3_CH4_solar_azimuth_angle                             5.235759
# dtype: float64

# %%
sqrt_skew_fix = [
    "L3_NO2_NO2_slant_column_number_density",
    "L3_HCHO_tropospheric_HCHO_column_number_density",
    "L3_NO2_NO2_column_number_density",
    "L3_CO_solar_azimuth_angle"
]

# %%
(df_train[skew_fix_cols]**2).skew().sort_values()
# Out:
# L3_CO_solar_azimuth_angle                              -1.075121
# L3_SO2_solar_azimuth_angle                             -1.041861
# L3_HCHO_solar_azimuth_angle                            -1.015646
# L3_CLOUD_solar_azimuth_angle                           -0.824799
# L3_AER_AI_solar_azimuth_angle                          -0.779791
# L3_O3_solar_azimuth_angle                              -0.757698
# L3_NO2_solar_azimuth_angle                             -0.637889
# L3_HCHO_tropospheric_HCHO_column_number_density         0.000000
# L3_NO2_NO2_column_number_density                        0.000000
# L3_NO2_tropospheric_NO2_column_number_density           0.000000
# L3_NO2_NO2_slant_column_number_density                  0.000000
# L3_CH4_solar_azimuth_angle                              0.308086
# L3_AER_AI_sensor_altitude                               1.253738
# L3_NO2_cloud_fraction                                   1.684238
# L3_HCHO_tropospheric_HCHO_column_number_density_amf     2.731488
# L3_CLOUD_cloud_optical_depth                            8.012689
# L3_CO_CO_column_number_density                         21.733206
# dtype: float64

# %%
(df_train[skew_fix_cols]**2).skew().sort_values()[7:12].index
# Out:
# Index(['L3_HCHO_tropospheric_HCHO_column_number_density',
#        'L3_NO2_NO2_column_number_density',
#        'L3_NO2_tropospheric_NO2_column_number_density',
#        'L3_NO2_NO2_slant_column_number_density', 'L3_CH4_solar_azimuth_angle'],
#       dtype='object')

# %%
pow_skew_fix = ['L3_HCHO_tropospheric_HCHO_column_number_density',
       'L3_NO2_NO2_column_number_density',
       'L3_NO2_tropospheric_NO2_column_number_density',
       'L3_NO2_NO2_slant_column_number_density', 'L3_CH4_solar_azimuth_angle']

# %%
len(skew_fix_cols)
# Out:
# 17

# %% [markdown]
# ### Insights
# - skewed data could shift the mean, making it a worse representative

# %%
## checking months out
months = pd.to_datetime(df_train["Date"]).dt.month
pd.concat([df_train["target"], months], axis=1).corr()
# Out:
#         target    Date
# target  1.0000 -0.1228
# Date   -0.1228  1.0000

# %% [markdown]
# #### Class to handle data preprocesssing

# %%
class Cleaner():
    def __init__(self):
        self.cols_to_rem = [
            'L3_CH4_solar_zenith_angle',
            'L3_CH4_sensor_zenith_angle',
            'L3_CH4_sensor_azimuth_angle',
            'L3_CH4_aerosol_optical_depth',
            'L3_CH4_aerosol_height',
            'L3_CH4_CH4_column_volume_mixing_ratio_dry_air'         
        ]
    
        self.train_only_cols = ['target_min', 'target_variance', 'target_max', 'target_count']
    
        ## get medians and means from train and fill with them
        self.mean_fill_cols = ["L3_CLOUD_cloud_top_pressure",
                          "L3_SO2_absorbing_aerosol_index",
                          "L3_HCHO_HCHO_slant_column_number_density",
                          "L3_CLOUD_cloud_fraction",
                          "L3_O3_cloud_fraction",
                          'u_component_of_wind_10m_above_ground'
                         ]
    
        self.median_fill_cols = ["L3_HCHO_tropospheric_HCHO_column_number_density",
                            "L3_CO_CO_column_number_density",
                            "L3_NO2_NO2_slant_column_number_density",
                            "L3_NO2_tropospheric_NO2_column_number_density",
                            "L3_NO2_NO2_column_number_density",
                            'L3_HCHO_tropospheric_HCHO_column_number_density_amf',
                             'L3_CLOUD_cloud_optical_depth',
                             'u_component_of_wind_10m_above_ground',
                             'L3_CO_solar_azimuth_angle',
                             'L3_NO2_solar_azimuth_angle',
                             'L3_SO2_solar_azimuth_angle',
                             'L3_HCHO_solar_azimuth_angle',
                             'L3_O3_solar_azimuth_angle',
                             'L3_CLOUD_solar_azimuth_angle',
                             'L3_AER_AI_solar_azimuth_angle',
                             'L3_AER_AI_sensor_altitude',
                            "L3_NO2_cloud_fraction"
                           ]
    
        self.sqrt_skew_fix = ["L3_NO2_NO2_slant_column_number_density",
                        ]
    
        self.pow_skew_fix = ['L3_HCHO_tropospheric_HCHO_column_number_density',
                        'L3_NO2_NO2_column_number_density',
                        'L3_NO2_tropospheric_NO2_column_number_density',
                        'L3_NO2_NO2_slant_column_number_density',
                       ]

        self.quad_skew_fix=["L3_CO_solar_azimuth_angle"]
        
    def fit(self, train):

        self.means = train[self.mean_fill_cols].mean()
        self.medians = train[self.median_fill_cols].median()
        
    ## function for preprocessing
    def transform(self, df, train=True):
    
        df = df.drop(self.cols_to_rem, axis=1)
    
        ## remove the train-only features if train is true
        if train: df = df.drop(self.train_only_cols, axis=1)

        ## filling with means
        for col in self.mean_fill_cols:
            df[col] = df[col].fillna(self.means[col])
        ## filling with medians
        for col in self.median_fill_cols:
            df[col] = df[col].fillna(self.medians[col])

        ## fixing skew with sqrt
        for col in self.sqrt_skew_fix:
            df[col] = np.sqrt(df[col])
        ## fixing skew with square
        for col in self.pow_skew_fix:
            df[col] = df[col]**2
        ## fixing skew with quad
        for col in self.quad_skew_fix:
            df[col] = df[col]**4

        ## getting month column
        df["Month"] = pd.to_datetime(df["Date"]).dt.month
        df = df.drop("Date", axis=1)

        df = df.ffill()
        df = df.bfill()

        return df

# %%
data_cleaner = Cleaner()
data_cleaner.fit(df_train)

# %%
temp_df = data_cleaner.transform(df_train)
# df_fixed.transform(df_train).isna().sum().sort_values(ascending=False)[:20]

# %%
temp_df.isna().sum().sort_values(ascending=False)[:20]
# Out:
# Place_ID X Date                                        0
# Place_ID                                               0
# L3_CLOUD_solar_azimuth_angle                           0
# L3_CLOUD_sensor_zenith_angle                           0
# L3_CLOUD_sensor_azimuth_angle                          0
# L3_CLOUD_cloud_top_pressure                            0
# L3_CLOUD_cloud_top_height                              0
# L3_CLOUD_cloud_optical_depth                           0
# L3_CLOUD_cloud_fraction                                0
# L3_CLOUD_cloud_base_pressure                           0
# L3_CLOUD_cloud_base_height                             0
# L3_HCHO_tropospheric_HCHO_column_number_density_amf    0
# L3_HCHO_tropospheric_HCHO_column_number_density        0
# L3_HCHO_solar_zenith_angle                             0
# L3_HCHO_solar_azimuth_angle                            0
# L3_HCHO_sensor_zenith_angle                            0
# L3_HCHO_sensor_azimuth_angle                           0
# L3_CLOUD_solar_zenith_angle                            0
# L3_CLOUD_surface_albedo                                0
# L3_AER_AI_absorbing_aerosol_index                      0
# dtype: int64

# %%
## sanity check
"Date" in temp_df
# Out:
# False

# %% [markdown]
# #### Checking whether certain combinations of features might lead to more accurate prediction

# %%
## checking some combinations out
def check_comb(df, col, func = lambda a, b: a*b):
    # df = df.sample(frac=0.4)
    cols = df.select_dtypes("number").columns
    cols = [c for c in cols if c not in ['target', 'target_min', 'target_variance', 'target_max', 'target_count', col]]
    result = []

    _min=_max=0
    _min_col = ""
    _max_col = ""
    for ccol in cols:
        val = func(df[col], df[ccol]).corr(df["target"])
        if val > _max:
            _max = val
            _max_col = ccol
        if val < _min:
            _min = val
            _min_col = ccol
        # result.append((f"{ccol}---{col}", val))

    return (f"{ccol}---{col}", _max_col, _max, _min_col, _min)

# %%
# pd.DataFrame(check_comb(temp_df, "L3_HCHO_cloud_fraction")).sort_values(by=1, ascending=False)
num_cols = temp_df.drop("target", axis=1).select_dtypes("number").columns

# check_comb(temp_df, "L3_HCHO_cloud_fraction")
mult_combs = pd.DataFrame([check_comb(temp_df, col) for col in num_cols], columns=["feature", "max_feature", "max", "min_feature", "min"])

# %%
mult_combs.sort_values(by="max", ascending=False)
# Out:
#                                              feature  \
# 25            Month---L3_CO_CO_column_number_density
# 7     Month---L3_NO2_NO2_slant_column_number_density
# 53                 Month---L3_AER_AI_sensor_altitude
# 33  Month---L3_HCHO_HCHO_slant_column_number_density
# 19            Month---L3_O3_O3_effective_temperature
# ..                                               ...
# 35              Month---L3_HCHO_sensor_azimuth_angle
# 63               Month---L3_SO2_sensor_azimuth_angle
# 29                Month---L3_CO_sensor_azimuth_angle
# 58          Month---L3_SO2_SO2_column_number_density
# 5       Month---v_component_of_wind_10m_above_ground
#
#                                max_feature       max  \
# 25  L3_NO2_NO2_slant_column_number_density  0.380433
# 7           L3_CO_CO_column_number_density  0.380433
# 53          L3_CO_CO_column_number_density  0.340508
# 33          L3_CO_CO_column_number_density  0.337054
# 19          L3_CO_CO_column_number_density  0.336283
# ..                                     ...       ...
# 35          L3_AER_AI_sensor_azimuth_angle  0.109649
# 63          L3_AER_AI_sensor_azimuth_angle  0.109000
# 29          L3_AER_AI_sensor_azimuth_angle  0.089557
# 58        L3_NO2_NO2_column_number_density  0.081771
# 5           L3_NO2_absorbing_aerosol_index  0.056851
#
#                                       min_feature       min
# 25                  L3_AER_AI_solar_azimuth_angle -0.310807
# 7                   L3_AER_AI_solar_azimuth_angle -0.333517
# 53                  L3_AER_AI_solar_azimuth_angle -0.191169
# 33                  L3_AER_AI_solar_azimuth_angle -0.328126
# 19                  L3_AER_AI_solar_azimuth_angle -0.195263
# ..                                            ...       ...
# 35               L3_NO2_NO2_column_number_density -0.037524
# 63  L3_NO2_tropospheric_NO2_column_number_density -0.034976
# 29               L3_NO2_NO2_column_number_density -0.018796
# 58                  L3_AER_AI_solar_azimuth_angle -0.040644
# 5                            L3_O3_cloud_fraction -0.085425
#
# [69 rows x 5 columns]

# %%
sub_combs = pd.DataFrame([check_comb(temp_df, col,func=lambda a,b: a-b) for col in num_cols], columns=["feature", "max_feature", "max", "min_feature", "min"])
# Out:
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\_methods.py:118: RuntimeWarning: invalid value encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Users\Eli\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]

# %%
sub_combs.sort_values(by="min", ascending=False)
# Out:
#                                          feature  \
# 46             Month_L3_CLOUD_cloud_top_pressure
# 60  Month_L3_SO2_SO2_slant_column_number_density
# 58        Month_L3_SO2_SO2_column_number_density
# 48            Month_L3_CLOUD_sensor_zenith_angle
# 29              Month_L3_CO_sensor_azimuth_angle
# ..                                           ...
# 10                  Month_L3_NO2_sensor_altitude
# 28                   Month_L3_CO_sensor_altitude
# 14               Month_L3_NO2_solar_zenith_angle
# 18          Month_L3_O3_O3_column_number_density
# 16              Month_L3_NO2_tropopause_pressure
#
#                              max_feature       max  \
# 46                                 Month  0.181562
# 60  precipitable_water_entire_atmosphere  0.078389
# 58  precipitable_water_entire_atmosphere  0.054798
# 48          L3_CLOUD_cloud_optical_depth  0.109748
# 29        L3_CO_CO_column_number_density  0.028641
# ..                                   ...       ...
# 10            L3_NO2_tropopause_pressure  0.166976
# 28          L3_CLOUD_cloud_optical_depth  0.150772
# 14            L3_NO2_tropopause_pressure  0.174332
# 18          L3_CLOUD_cloud_optical_depth  0.116877
# 16     specific_humidity_2m_above_ground  0.084375
#
#                                min_feature       min
# 46             temperature_2m_above_ground -0.008616
# 60          L3_SO2_absorbing_aerosol_index -0.023982
# 58          L3_SO2_absorbing_aerosol_index -0.027566
# 48             L3_CLOUD_cloud_top_pressure -0.048324
# 29               L3_CLOUD_cloud_top_height -0.049375
# ..                                     ...       ...
# 10  L3_NO2_NO2_slant_column_number_density -0.276331
# 28          L3_CO_CO_column_number_density -0.280457
# 14  L3_NO2_NO2_slant_column_number_density -0.295823
# 18          L3_CO_CO_column_number_density -0.301602
# 16  L3_NO2_NO2_slant_column_number_density -0.345988
#
# [69 rows x 5 columns]

# %% [markdown]
# ### Final Preprocesser

# %%
class Cleaner():
    def __init__(self):
        self.cols_to_rem = [
            'L3_CH4_solar_zenith_angle',
            'L3_CH4_sensor_zenith_angle',
            'L3_CH4_sensor_azimuth_angle',
            'L3_CH4_aerosol_optical_depth',
            'L3_CH4_aerosol_height',
            'L3_CH4_CH4_column_volume_mixing_ratio_dry_air'         
        ]

        self.more_cols_to_rem = ['L3_O3_sensor_azimuth_angle', 'L3_CLOUD_sensor_azimuth_angle',
                                 'L3_AER_AI_sensor_zenith_angle', 'L3_CO_H2O_column_number_density',
                                 'L3_AER_AI_sensor_azimuth_angle',
                                 'L3_SO2_SO2_column_number_density_amf', 'L3_NO2_solar_zenith_angle',
                                 'L3_CLOUD_sensor_zenith_angle', 'L3_NO2_sensor_azimuth_angle',
                                 'L3_CO_sensor_zenith_angle', 'L3_HCHO_sensor_azimuth_angle',
                                 'L3_CO_sensor_altitude', 'L3_CO_sensor_azimuth_angle',
                                 'L3_O3_sensor_zenith_angle', 'L3_HCHO_sensor_zenith_angle',
                                 'L3_SO2_sensor_azimuth_angle', 'L3_HCHO_cloud_fraction',
                                 'L3_SO2_sensor_zenith_angle', 'L3_SO2_SO2_column_number_density',
                                 'L3_SO2_cloud_fraction', 'precipitable_water_entire_atmosphere',
                                 'L3_NO2_absorbing_aerosol_index', 'specific_humidity_2m_above_ground',
                                 'L3_SO2_solar_zenith_angle', 'temperature_2m_above_ground',
                                 'L3_O3_solar_zenith_angle', 'L3_HCHO_solar_zenith_angle',
                                 'L3_NO2_sensor_zenith_angle', 'L3_SO2_SO2_slant_column_number_density',
                                 'L3_CLOUD_surface_albedo']
    
        self.train_only_cols = ['target_min', 'target_variance', 'target_max', 'target_count']
    
        ## get medians and means from train and fill with them
        self.mean_fill_cols = ["L3_CLOUD_cloud_top_pressure",
                          "L3_SO2_absorbing_aerosol_index",
                          "L3_HCHO_HCHO_slant_column_number_density",
                          "L3_CLOUD_cloud_fraction",
                          "L3_O3_cloud_fraction",
                          'u_component_of_wind_10m_above_ground'
                         ]
    
        self.median_fill_cols = ["L3_HCHO_tropospheric_HCHO_column_number_density",
                            "L3_CO_CO_column_number_density",
                            "L3_NO2_NO2_slant_column_number_density",
                            "L3_NO2_tropospheric_NO2_column_number_density",
                            "L3_NO2_NO2_column_number_density",
                            'L3_HCHO_tropospheric_HCHO_column_number_density_amf',
                             'L3_CLOUD_cloud_optical_depth',
                             'u_component_of_wind_10m_above_ground',
                             'L3_CO_solar_azimuth_angle',
                             'L3_NO2_solar_azimuth_angle',
                             'L3_SO2_solar_azimuth_angle',
                             'L3_HCHO_solar_azimuth_angle',
                             'L3_O3_solar_azimuth_angle',
                             'L3_CLOUD_solar_azimuth_angle',
                             'L3_AER_AI_solar_azimuth_angle',
                             'L3_AER_AI_sensor_altitude',
                            "L3_NO2_cloud_fraction"
                           ]
    
        self.sqrt_skew_fix = ["L3_NO2_NO2_slant_column_number_density",
                        ]
    
        self.pow_skew_fix = ['L3_HCHO_tropospheric_HCHO_column_number_density',
                        'L3_NO2_NO2_column_number_density',
                        'L3_NO2_tropospheric_NO2_column_number_density',
                        'L3_NO2_NO2_slant_column_number_density',
                       ]

        self.mult_cols = [("Month","L3_CO_CO_column_number_density")]

        self.quad_skew_fix=["L3_CO_solar_azimuth_angle"]

    def apply(self, df, col1, col2, func):
        return func(df[col1], df[col2])
        
    def fit(self, train):

        self.means = train[self.mean_fill_cols].mean()
        self.medians = train[self.median_fill_cols].median()
        
    ## function for preprocessing
    def transform(self, df, train=True):
    
        df = df.drop(self.cols_to_rem+self.more_cols_to_rem, axis=1)
    
        ## remove the train-only features if train is true
        if train: df = df.drop(self.train_only_cols, axis=1)

        ## filling with means
        for col in self.mean_fill_cols:
            df[col] = df[col].fillna(self.means[col])
        ## filling with medians
        for col in self.median_fill_cols:
            df[col] = df[col].fillna(self.medians[col])

        ## fixing skew with sqrt
        for col in self.sqrt_skew_fix:
            df[col] = np.sqrt(df[col])
        ## fixing skew with square
        for col in self.pow_skew_fix:
            df[col] = df[col]**2
        ## fixing skew with quad
        for col in self.quad_skew_fix:
            df[col] = df[col]**4

        ## getting month column
        df["Month"] = pd.to_datetime(df["Date"]).dt.month
        df = df.drop("Date", axis=1)

        df = df.ffill()
        df = df.bfill()

        ## multiplying
        for col1, col2 in self.mult_cols:
            df[f"{col1}---{col2}"] = self.apply(df, col1, col2, func=lambda a,b: a*b)

        return df

# %%
data_cleaner = Cleaner()
data_cleaner.fit(df_train)
processed_train_df = data_cleaner.transform(df_train)
processed_test_df = data_cleaner.transform(df_test, train=False)

# %%
processed_test_df
# Out:
#             Place_ID X Date Place_ID  relative_humidity_2m_above_ground  \
# 0      0OS9LVX X 2020-01-02  0OS9LVX                          30.200001
# 1      0OS9LVX X 2020-01-03  0OS9LVX                          42.900002
# 2      0OS9LVX X 2020-01-04  0OS9LVX                          41.299999
# 3      0OS9LVX X 2020-01-05  0OS9LVX                          53.100002
# 4      0OS9LVX X 2020-01-06  0OS9LVX                          71.599998
# ...                     ...      ...                                ...
# 16131  ZZDJZMS X 2020-03-31  ZZDJZMS                          86.200005
# 16132  ZZDJZMS X 2020-04-01  ZZDJZMS                          90.300003
# 16133  ZZDJZMS X 2020-04-02  ZZDJZMS                          86.200005
# 16134  ZZDJZMS X 2020-04-03  ZZDJZMS                          66.400002
# 16135  ZZDJZMS X 2020-04-04  ZZDJZMS                          81.599998
#
#        u_component_of_wind_10m_above_ground  \
# 0                                  3.956377
# 1                                  4.230430
# 2                                  5.245728
# 3                                  5.454001
# 4                                  3.511787
# ...                                     ...
# 16131                              0.073416
# 16132                             -1.217649
# 16133                             -0.410603
# 16134                              1.659441
# 16135                             -1.004568
#
#        v_component_of_wind_10m_above_ground  L3_NO2_NO2_column_number_density  \
# 0                                  0.712605                      2.849625e-09
# 1                                  0.661892                      2.544961e-09
# 2                                  1.640559                      2.535508e-09
# 3                                 -0.190532                      3.024069e-09
# 4                                 -0.279441                      3.033837e-09
# ...                                     ...                               ...
# 16131                              0.923135                      0.000000e+00
# 16132                              1.270308                      0.000000e+00
# 16133                              0.754363                      0.000000e+00
# 16134                             -2.471616                      0.000000e+00
# 16135                              1.752161                      0.000000e+00
#
#        L3_NO2_NO2_slant_column_number_density  L3_NO2_cloud_fraction  \
# 0                                    0.000108               0.010752
# 1                                    0.000109               0.028307
# 2                                    0.000134               0.010374
# 3                                    0.000155               0.088795
# 4                                    0.000131               0.041197
# ...                                       ...                    ...
# 16131                                0.000000               0.000000
# 16132                                0.000000               0.000000
# 16133                                0.000000               0.000000
# 16134                                0.000000               0.000000
# 16135                                0.000000               0.000000
#
#        L3_NO2_sensor_altitude  L3_NO2_solar_azimuth_angle  ...  \
# 0               835670.492740                  -95.984984  ...
# 1               835281.882757                  -95.017976  ...
# 2               834839.050781                  -94.015418  ...
# 3               836269.833912                  -97.248047  ...
# 4               836043.111009                  -96.057236  ...
# ...                       ...                         ...  ...
# 16131                0.000000                    0.000000  ...
# 16132                0.000000                    0.000000  ...
# 16133                0.000000                    0.000000  ...
# 16134                0.000000                    0.000000  ...
# 16135                0.000000                    0.000000  ...
#
#        L3_CLOUD_solar_zenith_angle  L3_AER_AI_absorbing_aerosol_index  \
# 0                        22.942019                           0.466173
# 1                        18.539491                          -0.213657
# 2                        14.140820                          -0.254250
# 3                        32.730553                          -0.268491
# 4                        28.320527                           0.460720
# ...                            ...                                ...
# 16131                    38.857262                          -1.011116
# 16132                    40.886266                          -1.363941
# 16133                    41.197583                          -1.776128
# 16134                    39.431193                          -2.971064
# 16135                    38.047061                          -1.582332
#
#        L3_AER_AI_sensor_altitude  L3_AER_AI_solar_azimuth_angle  \
# 0                  835670.492740                     -95.984984
# 1                  835281.882757                     -95.017976
# 2                  834839.050781                     -94.015418
# 3                  836269.833912                     -97.248047
# 4                  836043.111009                     -96.057236
# ...                          ...                            ...
# 16131              833312.353691                    -176.521720
# 16132              833125.012462                      15.079379
# 16133              832573.386814                    -152.254156
# 16134              832687.223024                    -158.883352
# 16135              832878.418266                    -165.900429
#
#        L3_AER_AI_solar_zenith_angle  L3_SO2_absorbing_aerosol_index  \
# 0                         22.942019                       -0.140458
# 1                         18.539524                       -0.842713
# 2                         14.140820                       -0.716770
# 3                         32.730747                       -0.730104
# 4                         28.320528                       -0.108353
# ...                             ...                             ...
# 16131                     38.857262                       -1.944519
# 16132                     40.886310                       -1.956755
# 16133                     41.190326                       -2.667801
# 16134                     39.431193                        0.000000
# 16135                     38.047473                       -1.944519
#
#        L3_SO2_solar_azimuth_angle  L3_CH4_solar_azimuth_angle  Month  \
# 0                      -95.984984                  -95.910744      1
# 1                      -95.014908                  -95.910744      1
# 2                      -94.015418                  -95.910744      1
# 3                      -97.247602                  -95.910744      1
# 4                      -96.057265                  -95.910744      1
# ...                           ...                         ...    ...
# 16131                 -156.637162                    0.000000      3
# 16132                   45.983723                    0.000000      4
# 16133                 -152.281488                    0.000000      4
# 16134                    0.000000                    0.000000      4
# 16135                 -156.637162                    0.000000      4
#
#        Month---L3_CO_CO_column_number_density
# 0                                    0.017953
# 1                                    0.019576
# 2                                    0.018736
# 3                                    0.018304
# 4                                    0.018666
# ...                                       ...
# 16131                                0.092175
# 16132                                0.140267
# 16133                                0.138174
# 16134                                0.000000
# 16135                                0.127679
#
# [16136 rows x 42 columns]

# %% [markdown]
# ### Preparing for training

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, KFold

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor

from lightgbm import LGBMRegressor
from xgboost import XGBClassifier

# %% [markdown]
# #### Splitting variables into dependent and independents

# %%
X = processed_train_df.drop(["Place_ID X Date", "Place_ID", "target"], axis=1)
y = processed_train_df["target"]

# %% [markdown]
# #### Standard Scaling

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
processed_train_df.shape
# Out:
# (30557, 43)

# %% [markdown]
# ### Training

# %%
rs = 45
kf = KFold(n_splits = 5, shuffle=True, random_state=rs)

# %% [markdown]
# ##### Linear Regression

# %%
params = {
    "positive": [True, False]
}

grid_lr = GridSearchCV(LinearRegression(), params, scoring="neg_root_mean_squared_error", cv=kf, verbose=10)
grid_lr.fit(X,y)
# Out:
# Fitting 8 folds for each of 2 candidates, totalling 16 fits
# [CV 1/8; 1/2] START positive=True...............................................
# [CV 1/8; 1/2] END ..............positive=True;, score=-40.473 total time=   0.0s
# [CV 2/8; 1/2] START positive=True...............................................
# [CV 2/8; 1/2] END ..............positive=True;, score=-38.858 total time=   0.0s
# [CV 3/8; 1/2] START positive=True...............................................
# [CV 3/8; 1/2] END ..............positive=True;, score=-39.256 total time=   0.0s
# [CV 4/8; 1/2] START positive=True...............................................
# [CV 4/8; 1/2] END ..............positive=True;, score=-41.445 total time=   0.0s
# [CV 5/8; 1/2] START positive=True...............................................
# [CV 5/8; 1/2] END ..............positive=True;, score=-43.016 total time=   0.0s
# [CV 6/8; 1/2] START positive=True...............................................
# [CV 6/8; 1/2] END ..............positive=True;, score=-41.534 total time=   0.0s
# [CV 7/8; 1/2] START positive=True...............................................
# [CV 7/8; 1/2] END ..............positive=True;, score=-40.412 total time=   0.0s
# [CV 8/8; 1/2] START positive=True...............................................
# [CV 8/8; 1/2] END ..............positive=True;, score=-43.136 total time=   0.0s
# [CV 1/8; 2/2] START positive=False..............................................
# [CV 1/8; 2/2] END .............positive=False;, score=-37.165 total time=   0.0s
# [CV 2/8; 2/2] START positive=False..............................................
# [CV 2/8; 2/2] END .............positive=False;, score=-35.430 total time=   0.0s
# [CV 3/8; 2/2] START positive=False..............................................
# [CV 3/8; 2/2] END .............positive=False;, score=-36.295 total time=   0.0s
# [CV 4/8; 2/2] START positive=False..............................................
# [CV 4/8; 2/2] END .............positive=False;, score=-38.683 total time=   0.0s
# [CV 5/8; 2/2] START positive=False..............................................
# [CV 5/8; 2/2] END .............positive=False;, score=-40.280 total time=   0.0s
# [CV 6/8; 2/2] START positive=False..............................................
# [CV 6/8; 2/2] END .............positive=False;, score=-38.901 total time=   0.0s
# [CV 7/8; 2/2] START positive=False..............................................
# [CV 7/8; 2/2] END .............positive=False;, score=-37.463 total time=   0.0s
# [CV 8/8; 2/2] START positive=False..............................................
# [CV 8/8; 2/2] END .............positive=False;, score=-40.044 total time=   0.0s
# GridSearchCV(cv=KFold(n_splits=8, random_state=45, shuffle=True),
#              estimator=LinearRegression(),
#              param_grid={'positive': [True, False]},
#              scoring='neg_root_mean_squared_error', verbose=10)

# %%
print(grid_lr.best_score_)
print(grid_lr.best_params_)
# Out:
# -38.03266631601944
# {'positive': False}

# %% [markdown]
# ##### SVR

# %%
params = {
    "C": [0.5, 1, 1.5]
}

grid_svr = GridSearchCV(SVR(), params, scoring="neg_root_mean_squared_error", cv=kf, verbose=10)
grid_svr.fit(X,y)
# Out:
# Fitting 8 folds for each of 3 candidates, totalling 24 fits
# [CV 1/8; 1/3] START C=0.5.......................................................
# [CV 1/8; 1/3] END ......................C=0.5;, score=-38.140 total time= 1.2min
# [CV 2/8; 1/3] START C=0.5.......................................................
# [CV 2/8; 1/3] END ......................C=0.5;, score=-37.600 total time= 1.2min
# [CV 3/8; 1/3] START C=0.5.......................................................
# [CV 3/8; 1/3] END ......................C=0.5;, score=-37.320 total time= 1.2min
# [CV 4/8; 1/3] START C=0.5.......................................................
# [CV 4/8; 1/3] END ......................C=0.5;, score=-39.192 total time= 1.4min
# [CV 5/8; 1/3] START C=0.5.......................................................
# [CV 5/8; 1/3] END ......................C=0.5;, score=-40.925 total time= 1.3min
# [CV 6/8; 1/3] START C=0.5.......................................................
# [CV 6/8; 1/3] END ......................C=0.5;, score=-38.526 total time= 1.3min
# [CV 7/8; 1/3] START C=0.5.......................................................
# [CV 7/8; 1/3] END ......................C=0.5;, score=-38.025 total time= 1.3min
# [CV 8/8; 1/3] START C=0.5.......................................................
# [CV 8/8; 1/3] END ......................C=0.5;, score=-42.048 total time= 1.3min
# [CV 1/8; 2/3] START C=1.........................................................
# [CV 1/8; 2/3] END ........................C=1;, score=-36.476 total time= 1.4min
# [CV 2/8; 2/3] START C=1.........................................................
# [CV 2/8; 2/3] END ........................C=1;, score=-36.127 total time= 1.3min
# [CV 3/8; 2/3] START C=1.........................................................
# [CV 3/8; 2/3] END ........................C=1;, score=-35.737 total time= 1.6min
# [CV 4/8; 2/3] START C=1.........................................................
# [CV 4/8; 2/3] END ........................C=1;, score=-37.447 total time= 1.5min
# [CV 5/8; 2/3] START C=1.........................................................
# [CV 5/8; 2/3] END ........................C=1;, score=-39.495 total time= 1.5min
# [CV 6/8; 2/3] START C=1.........................................................
# [CV 6/8; 2/3] END ........................C=1;, score=-36.764 total time= 1.6min
# [CV 7/8; 2/3] START C=1.........................................................
# [CV 7/8; 2/3] END ........................C=1;, score=-36.198 total time= 1.6min
# [CV 8/8; 2/3] START C=1.........................................................
# [CV 8/8; 2/3] END ........................C=1;, score=-40.335 total time= 1.7min
# [CV 1/8; 3/3] START C=1.5.......................................................
# [CV 1/8; 3/3] END ......................C=1.5;, score=-35.630 total time= 1.6min
# [CV 2/8; 3/3] START C=1.5.......................................................
# [CV 2/8; 3/3] END ......................C=1.5;, score=-35.389 total time= 1.5min
# [CV 3/8; 3/3] START C=1.5.......................................................
# [CV 3/8; 3/3] END ......................C=1.5;, score=-34.968 total time= 1.6min
# [CV 4/8; 3/3] START C=1.5.......................................................
# [CV 4/8; 3/3] END ......................C=1.5;, score=-36.630 total time= 1.6min
# [CV 5/8; 3/3] START C=1.5.......................................................
# [CV 5/8; 3/3] END ......................C=1.5;, score=-38.831 total time= 1.8min
# [CV 6/8; 3/3] START C=1.5.......................................................
# [CV 6/8; 3/3] END ......................C=1.5;, score=-35.942 total time= 2.6min
# [CV 7/8; 3/3] START C=1.5.......................................................
# [CV 7/8; 3/3] END ......................C=1.5;, score=-35.313 total time= 2.7min
# [CV 8/8; 3/3] START C=1.5.......................................................
# [CV 8/8; 3/3] END ......................C=1.5;, score=-39.463 total time= 2.7min
# GridSearchCV(cv=KFold(n_splits=8, random_state=45, shuffle=True),
#              estimator=SVR(), param_grid={'C': [0.5, 1, 1.5]},
#              scoring='neg_root_mean_squared_error', verbose=10)

# %%
print(grid_svr.best_score_)
print(grid_svr.best_params_)

# -36.52081876651492
# {'C': 1.5}
# Out:
# -36.52081876651492
# {'C': 1.5}

# %% [markdown]
# ##### Decision Tree Regressor

# %%
params = {
    "criterion": ["friedman_mse", "squared_error", "absolute_error"],
    "max_depth": [2,4,6,8],
}

grid_dt = GridSearchCV(DecisionTreeRegressor(), params, scoring="neg_root_mean_squared_error", cv=kf, verbose=10)
grid_dt.fit(X,y)
# Out:
# Fitting 8 folds for each of 12 candidates, totalling 96 fits
# [CV 1/8; 1/12] START criterion=friedman_mse, max_depth=2........................
# [CV 1/8; 1/12] END criterion=friedman_mse, max_depth=2;, score=-41.538 total time=   2.0s
# [CV 2/8; 1/12] START criterion=friedman_mse, max_depth=2........................
# [CV 2/8; 1/12] END criterion=friedman_mse, max_depth=2;, score=-40.503 total time=   2.0s
# [CV 3/8; 1/12] START criterion=friedman_mse, max_depth=2........................
# [CV 3/8; 1/12] END criterion=friedman_mse, max_depth=2;, score=-40.434 total time=   2.0s
# [CV 4/8; 1/12] START criterion=friedman_mse, max_depth=2........................
# [CV 4/8; 1/12] END criterion=friedman_mse, max_depth=2;, score=-42.918 total time=   2.1s
# [CV 5/8; 1/12] START criterion=friedman_mse, max_depth=2........................
# [CV 5/8; 1/12] END criterion=friedman_mse, max_depth=2;, score=-44.299 total time=   2.1s
# [CV 6/8; 1/12] START criterion=friedman_mse, max_depth=2........................
# [CV 6/8; 1/12] END criterion=friedman_mse, max_depth=2;, score=-41.455 total time=   2.0s
# [CV 7/8; 1/12] START criterion=friedman_mse, max_depth=2........................
# [CV 7/8; 1/12] END criterion=friedman_mse, max_depth=2;, score=-41.368 total time=   2.0s
# [CV 8/8; 1/12] START criterion=friedman_mse, max_depth=2........................
# [CV 8/8; 1/12] END criterion=friedman_mse, max_depth=2;, score=-44.007 total time=   2.0s
# [CV 1/8; 2/12] START criterion=friedman_mse, max_depth=4........................
# [CV 1/8; 2/12] END criterion=friedman_mse, max_depth=4;, score=-39.026 total time=   4.0s
# [CV 2/8; 2/12] START criterion=friedman_mse, max_depth=4........................
# [CV 2/8; 2/12] END criterion=friedman_mse, max_depth=4;, score=-38.104 total time=   4.1s
# [CV 3/8; 2/12] START criterion=friedman_mse, max_depth=4........................
# [CV 3/8; 2/12] END criterion=friedman_mse, max_depth=4;, score=-37.659 total time=   4.1s
# [CV 4/8; 2/12] START criterion=friedman_mse, max_depth=4........................
# [CV 4/8; 2/12] END criterion=friedman_mse, max_depth=4;, score=-39.969 total time=   4.0s
# [CV 5/8; 2/12] START criterion=friedman_mse, max_depth=4........................
# [CV 5/8; 2/12] END criterion=friedman_mse, max_depth=4;, score=-41.741 total time=   4.2s
# [CV 6/8; 2/12] START criterion=friedman_mse, max_depth=4........................
# [CV 6/8; 2/12] END criterion=friedman_mse, max_depth=4;, score=-38.872 total time=   4.1s
# [CV 7/8; 2/12] START criterion=friedman_mse, max_depth=4........................
# [CV 7/8; 2/12] END criterion=friedman_mse, max_depth=4;, score=-38.500 total time=   4.0s
# [CV 8/8; 2/12] START criterion=friedman_mse, max_depth=4........................
# [CV 8/8; 2/12] END criterion=friedman_mse, max_depth=4;, score=-41.319 total time=   4.3s
# [CV 1/8; 3/12] START criterion=friedman_mse, max_depth=6........................
# [CV 1/8; 3/12] END criterion=friedman_mse, max_depth=6;, score=-36.959 total time=   6.4s
# [CV 2/8; 3/12] START criterion=friedman_mse, max_depth=6........................
# [CV 2/8; 3/12] END criterion=friedman_mse, max_depth=6;, score=-35.737 total time=   5.8s
# [CV 3/8; 3/12] START criterion=friedman_mse, max_depth=6........................
# [CV 3/8; 3/12] END criterion=friedman_mse, max_depth=6;, score=-35.802 total time=   6.1s
# [CV 4/8; 3/12] START criterion=friedman_mse, max_depth=6........................
# [CV 4/8; 3/12] END criterion=friedman_mse, max_depth=6;, score=-38.857 total time=   6.4s
# [CV 5/8; 3/12] START criterion=friedman_mse, max_depth=6........................
# [CV 5/8; 3/12] END criterion=friedman_mse, max_depth=6;, score=-40.357 total time=   5.9s
# [CV 6/8; 3/12] START criterion=friedman_mse, max_depth=6........................
# [CV 6/8; 3/12] END criterion=friedman_mse, max_depth=6;, score=-37.135 total time=   6.1s
# [CV 7/8; 3/12] START criterion=friedman_mse, max_depth=6........................
# [CV 7/8; 3/12] END criterion=friedman_mse, max_depth=6;, score=-36.201 total time=   6.2s
# [CV 8/8; 3/12] START criterion=friedman_mse, max_depth=6........................
# [CV 8/8; 3/12] END criterion=friedman_mse, max_depth=6;, score=-39.114 total time=   6.1s
# [CV 1/8; 4/12] START criterion=friedman_mse, max_depth=8........................
# [CV 1/8; 4/12] END criterion=friedman_mse, max_depth=8;, score=-35.809 total time=   8.3s
# [CV 2/8; 4/12] START criterion=friedman_mse, max_depth=8........................
# [CV 2/8; 4/12] END criterion=friedman_mse, max_depth=8;, score=-38.817 total time=   8.0s
# [CV 3/8; 4/12] START criterion=friedman_mse, max_depth=8........................
# [CV 3/8; 4/12] END criterion=friedman_mse, max_depth=8;, score=-34.570 total time=   8.0s
# [CV 4/8; 4/12] START criterion=friedman_mse, max_depth=8........................
# [CV 4/8; 4/12] END criterion=friedman_mse, max_depth=8;, score=-37.055 total time=   8.0s
# [CV 5/8; 4/12] START criterion=friedman_mse, max_depth=8........................
# [CV 5/8; 4/12] END criterion=friedman_mse, max_depth=8;, score=-40.003 total time=   8.0s
# [CV 6/8; 4/12] START criterion=friedman_mse, max_depth=8........................
# [CV 6/8; 4/12] END criterion=friedman_mse, max_depth=8;, score=-37.361 total time=   8.0s
# [CV 7/8; 4/12] START criterion=friedman_mse, max_depth=8........................
# [CV 7/8; 4/12] END criterion=friedman_mse, max_depth=8;, score=-35.735 total time=   8.2s
# [CV 8/8; 4/12] START criterion=friedman_mse, max_depth=8........................
# [CV 8/8; 4/12] END criterion=friedman_mse, max_depth=8;, score=-38.442 total time=   8.2s
# [CV 1/8; 5/12] START criterion=squared_error, max_depth=2.......................
# [CV 1/8; 5/12] END criterion=squared_error, max_depth=2;, score=-41.538 total time=   2.0s
# [CV 2/8; 5/12] START criterion=squared_error, max_depth=2.......................
# [CV 2/8; 5/12] END criterion=squared_error, max_depth=2;, score=-40.503 total time=   2.1s
# [CV 3/8; 5/12] START criterion=squared_error, max_depth=2.......................
# [CV 3/8; 5/12] END criterion=squared_error, max_depth=2;, score=-40.434 total time=   2.1s
# [CV 4/8; 5/12] START criterion=squared_error, max_depth=2.......................
# [CV 4/8; 5/12] END criterion=squared_error, max_depth=2;, score=-42.918 total time=   2.1s
# [CV 5/8; 5/12] START criterion=squared_error, max_depth=2.......................
# [CV 5/8; 5/12] END criterion=squared_error, max_depth=2;, score=-44.299 total time=   2.0s
# [CV 6/8; 5/12] START criterion=squared_error, max_depth=2.......................
# [CV 6/8; 5/12] END criterion=squared_error, max_depth=2;, score=-41.455 total time=   2.0s
# [CV 7/8; 5/12] START criterion=squared_error, max_depth=2.......................
# [CV 7/8; 5/12] END criterion=squared_error, max_depth=2;, score=-41.368 total time=   2.0s
# [CV 8/8; 5/12] START criterion=squared_error, max_depth=2.......................
# [CV 8/8; 5/12] END criterion=squared_error, max_depth=2;, score=-44.007 total time=   2.1s
# [CV 1/8; 6/12] START criterion=squared_error, max_depth=4.......................
# [CV 1/8; 6/12] END criterion=squared_error, max_depth=4;, score=-39.026 total time=   4.2s
# [CV 2/8; 6/12] START criterion=squared_error, max_depth=4.......................
# [CV 2/8; 6/12] END criterion=squared_error, max_depth=4;, score=-38.104 total time=   4.0s
# [CV 3/8; 6/12] START criterion=squared_error, max_depth=4.......................
# [CV 3/8; 6/12] END criterion=squared_error, max_depth=4;, score=-37.659 total time=   4.4s
# [CV 4/8; 6/12] START criterion=squared_error, max_depth=4.......................
# [CV 4/8; 6/12] END criterion=squared_error, max_depth=4;, score=-39.969 total time=   4.3s
# [CV 5/8; 6/12] START criterion=squared_error, max_depth=4.......................
# [CV 5/8; 6/12] END criterion=squared_error, max_depth=4;, score=-41.741 total time=   4.0s
# [CV 6/8; 6/12] START criterion=squared_error, max_depth=4.......................
# [CV 6/8; 6/12] END criterion=squared_error, max_depth=4;, score=-38.872 total time=   4.2s
# [CV 7/8; 6/12] START criterion=squared_error, max_depth=4.......................
# [CV 7/8; 6/12] END criterion=squared_error, max_depth=4;, score=-38.500 total time=   4.1s
# [CV 8/8; 6/12] START criterion=squared_error, max_depth=4.......................
# [CV 8/8; 6/12] END criterion=squared_error, max_depth=4;, score=-41.319 total time=   4.1s
# [CV 1/8; 7/12] START criterion=squared_error, max_depth=6.......................
# [CV 1/8; 7/12] END criterion=squared_error, max_depth=6;, score=-36.959 total time=   6.0s
# [CV 2/8; 7/12] START criterion=squared_error, max_depth=6.......................
# [CV 2/8; 7/12] END criterion=squared_error, max_depth=6;, score=-35.762 total time=   6.0s
# [CV 3/8; 7/12] START criterion=squared_error, max_depth=6.......................
# [CV 3/8; 7/12] END criterion=squared_error, max_depth=6;, score=-35.802 total time=   6.1s
# [CV 4/8; 7/12] START criterion=squared_error, max_depth=6.......................
# [CV 4/8; 7/12] END criterion=squared_error, max_depth=6;, score=-37.819 total time=   6.1s
# [CV 5/8; 7/12] START criterion=squared_error, max_depth=6.......................
# [CV 5/8; 7/12] END criterion=squared_error, max_depth=6;, score=-40.407 total time=   6.0s
# [CV 6/8; 7/12] START criterion=squared_error, max_depth=6.......................
# [CV 6/8; 7/12] END criterion=squared_error, max_depth=6;, score=-37.135 total time=   6.1s
# [CV 7/8; 7/12] START criterion=squared_error, max_depth=6.......................
# [CV 7/8; 7/12] END criterion=squared_error, max_depth=6;, score=-36.201 total time=   6.0s
# [CV 8/8; 7/12] START criterion=squared_error, max_depth=6.......................
# [CV 8/8; 7/12] END criterion=squared_error, max_depth=6;, score=-39.140 total time=   6.0s
# [CV 1/8; 8/12] START criterion=squared_error, max_depth=8.......................
# [CV 1/8; 8/12] END criterion=squared_error, max_depth=8;, score=-35.500 total time=   8.6s
# [CV 2/8; 8/12] START criterion=squared_error, max_depth=8.......................
# [CV 2/8; 8/12] END criterion=squared_error, max_depth=8;, score=-34.847 total time=   8.0s
# [CV 3/8; 8/12] START criterion=squared_error, max_depth=8.......................
# [CV 3/8; 8/12] END criterion=squared_error, max_depth=8;, score=-34.455 total time=   8.0s
# [CV 4/8; 8/12] START criterion=squared_error, max_depth=8.......................
# [CV 4/8; 8/12] END criterion=squared_error, max_depth=8;, score=-36.847 total time=   8.1s
# [CV 5/8; 8/12] START criterion=squared_error, max_depth=8.......................
# [CV 5/8; 8/12] END criterion=squared_error, max_depth=8;, score=-40.555 total time=   8.3s
# [CV 6/8; 8/12] START criterion=squared_error, max_depth=8.......................
# [CV 6/8; 8/12] END criterion=squared_error, max_depth=8;, score=-37.427 total time=   8.0s
# [CV 7/8; 8/12] START criterion=squared_error, max_depth=8.......................
# [CV 7/8; 8/12] END criterion=squared_error, max_depth=8;, score=-35.672 total time=   8.0s
# [CV 8/8; 8/12] START criterion=squared_error, max_depth=8.......................
# [CV 8/8; 8/12] END criterion=squared_error, max_depth=8;, score=-38.483 total time=   8.4s
# [CV 1/8; 9/12] START criterion=absolute_error, max_depth=2......................
# [CV 1/8; 9/12] END criterion=absolute_error, max_depth=2;, score=-42.786 total time= 6.4min
# [CV 2/8; 9/12] START criterion=absolute_error, max_depth=2......................
# [CV 2/8; 9/12] END criterion=absolute_error, max_depth=2;, score=-41.973 total time= 5.8min
# [CV 3/8; 9/12] START criterion=absolute_error, max_depth=2......................
# [CV 3/8; 9/12] END criterion=absolute_error, max_depth=2;, score=-40.956 total time= 6.2min
# [CV 4/8; 9/12] START criterion=absolute_error, max_depth=2......................
# [CV 4/8; 9/12] END criterion=absolute_error, max_depth=2;, score=-44.284 total time= 5.9min
# [CV 5/8; 9/12] START criterion=absolute_error, max_depth=2......................
# [CV 5/8; 9/12] END criterion=absolute_error, max_depth=2;, score=-45.261 total time= 5.8min
# [CV 6/8; 9/12] START criterion=absolute_error, max_depth=2......................
# [CV 6/8; 9/12] END criterion=absolute_error, max_depth=2;, score=-43.199 total time= 6.2min
# [CV 7/8; 9/12] START criterion=absolute_error, max_depth=2......................
# [CV 7/8; 9/12] END criterion=absolute_error, max_depth=2;, score=-42.660 total time= 6.4min
# [CV 8/8; 9/12] START criterion=absolute_error, max_depth=2......................
# [CV 8/8; 9/12] END criterion=absolute_error, max_depth=2;, score=-45.265 total time= 6.6min
# [CV 1/8; 10/12] START criterion=absolute_error, max_depth=4.....................
# [CV 1/8; 10/12] END criterion=absolute_error, max_depth=4;, score=-40.019 total time= 8.8min
# [CV 2/8; 10/12] START criterion=absolute_error, max_depth=4.....................
# [CV 2/8; 10/12] END criterion=absolute_error, max_depth=4;, score=-38.863 total time= 8.2min
# [CV 3/8; 10/12] START criterion=absolute_error, max_depth=4.....................
# [CV 3/8; 10/12] END criterion=absolute_error, max_depth=4;, score=-38.571 total time= 8.4min
# [CV 4/8; 10/12] START criterion=absolute_error, max_depth=4.....................
# [CV 4/8; 10/12] END criterion=absolute_error, max_depth=4;, score=-40.923 total time= 8.1min
# [CV 5/8; 10/12] START criterion=absolute_error, max_depth=4.....................
# [CV 5/8; 10/12] END criterion=absolute_error, max_depth=4;, score=-42.887 total time= 8.4min
# [CV 6/8; 10/12] START criterion=absolute_error, max_depth=4.....................
# [CV 6/8; 10/12] END criterion=absolute_error, max_depth=4;, score=-40.081 total time= 9.0min
# [CV 7/8; 10/12] START criterion=absolute_error, max_depth=4.....................
# [CV 7/8; 10/12] END criterion=absolute_error, max_depth=4;, score=-39.554 total time= 8.8min
# [CV 8/8; 10/12] START criterion=absolute_error, max_depth=4.....................
# [CV 8/8; 10/12] END criterion=absolute_error, max_depth=4;, score=-42.513 total time= 8.4min
# [CV 1/8; 11/12] START criterion=absolute_error, max_depth=6.....................
# [CV 1/8; 11/12] END criterion=absolute_error, max_depth=6;, score=-38.158 total time= 6.4min
# [CV 2/8; 11/12] START criterion=absolute_error, max_depth=6.....................
# [CV 2/8; 11/12] END criterion=absolute_error, max_depth=6;, score=-37.239 total time= 4.6min
# [CV 3/8; 11/12] START criterion=absolute_error, max_depth=6.....................
# [CV 3/8; 11/12] END criterion=absolute_error, max_depth=6;, score=-37.168 total time= 5.1min
# [CV 4/8; 11/12] START criterion=absolute_error, max_depth=6.....................
# [CV 4/8; 11/12] END criterion=absolute_error, max_depth=6;, score=-38.854 total time= 4.9min
# [CV 5/8; 11/12] START criterion=absolute_error, max_depth=6.....................
# [CV 5/8; 11/12] END criterion=absolute_error, max_depth=6;, score=-41.200 total time= 5.0min
# [CV 6/8; 11/12] START criterion=absolute_error, max_depth=6.....................
# [CV 6/8; 11/12] END criterion=absolute_error, max_depth=6;, score=-38.507 total time= 6.1min
# [CV 7/8; 11/12] START criterion=absolute_error, max_depth=6.....................
# [CV 7/8; 11/12] END criterion=absolute_error, max_depth=6;, score=-37.480 total time= 9.7min
# [CV 8/8; 11/12] START criterion=absolute_error, max_depth=6.....................
# [CV 8/8; 11/12] END criterion=absolute_error, max_depth=6;, score=-37.966 total time= 9.3min
# [CV 1/8; 12/12] START criterion=absolute_error, max_depth=8.....................
# [CV 1/8; 12/12] END criterion=absolute_error, max_depth=8;, score=-36.755 total time= 5.2min
# [CV 2/8; 12/12] START criterion=absolute_error, max_depth=8.....................
# [CV 2/8; 12/12] END criterion=absolute_error, max_depth=8;, score=-38.539 total time= 5.8min
# [CV 3/8; 12/12] START criterion=absolute_error, max_depth=8.....................
# [CV 3/8; 12/12] END criterion=absolute_error, max_depth=8;, score=-38.967 total time= 7.5min
# [CV 4/8; 12/12] START criterion=absolute_error, max_depth=8.....................
# [CV 4/8; 12/12] END criterion=absolute_error, max_depth=8;, score=-37.926 total time= 5.6min
# [CV 5/8; 12/12] START criterion=absolute_error, max_depth=8.....................
# [CV 5/8; 12/12] END criterion=absolute_error, max_depth=8;, score=-40.391 total time= 5.1min
# [CV 6/8; 12/12] START criterion=absolute_error, max_depth=8.....................
# [CV 6/8; 12/12] END criterion=absolute_error, max_depth=8;, score=-36.588 total time= 5.6min
# [CV 7/8; 12/12] START criterion=absolute_error, max_depth=8.....................
# [CV 7/8; 12/12] END criterion=absolute_error, max_depth=8;, score=-36.188 total time= 6.2min
# [CV 8/8; 12/12] START criterion=absolute_error, max_depth=8.....................
# [CV 8/8; 12/12] END criterion=absolute_error, max_depth=8;, score=-36.905 total time= 6.7min
# GridSearchCV(cv=KFold(n_splits=8, random_state=45, shuffle=True),
#              estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['friedman_mse', 'squared_error',
#                                        'absolute_error'],
#                          'max_depth': [2, 4, 6, 8]},
#              scoring='neg_root_mean_squared_error', verbose=10)

# %%
print(grid_dt.best_score_)
print(grid_dt.best_params_)

# -36.72326550129813
# {'criterion': 'squared_error', 'max_depth': 8}
# Out:
# -36.72326550129813
# {'criterion': 'squared_error', 'max_depth': 8}

# %% [markdown]
# ##### Random Forest Regressor

# %%
params = {
    "n_estimators": [100,500,1000],
    "max_depth": [2,4,6,8],
}

grid_rfc = GridSearchCV(RandomForestRegressor(), params, scoring="neg_root_mean_squared_error", cv=kf, verbose=10)
grid_rfc.fit(X,y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START max_depth=2, n_estimators=100..............................
# [CV 1/5; 1/12] END max_depth=2, n_estimators=100;, score=-41.361 total time= 1.5min
# [CV 2/5; 1/12] START max_depth=2, n_estimators=100..............................
# [CV 2/5; 1/12] END max_depth=2, n_estimators=100;, score=-40.182 total time= 1.4min
# [CV 3/5; 1/12] START max_depth=2, n_estimators=100..............................
# [CV 3/5; 1/12] END max_depth=2, n_estimators=100;, score=-43.565 total time= 1.4min
# [CV 4/5; 1/12] START max_depth=2, n_estimators=100..............................
# [CV 4/5; 1/12] END max_depth=2, n_estimators=100;, score=-41.333 total time= 1.4min
# [CV 5/5; 1/12] START max_depth=2, n_estimators=100..............................
# [CV 5/5; 1/12] END max_depth=2, n_estimators=100;, score=-42.940 total time= 1.4min
# [CV 1/5; 2/12] START max_depth=2, n_estimators=500..............................
# [CV 1/5; 2/12] END max_depth=2, n_estimators=500;, score=-41.386 total time= 7.2min
# [CV 2/5; 2/12] START max_depth=2, n_estimators=500..............................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[202], line 7
#       1 params = {
#       2     "n_estimators": [100,500,1000],
#       3     "max_depth": [2,4,6,8],
#       4 }
#       6 grid_rfc = GridSearchCV(RandomForestRegressor(), params, scoring="neg_root_mean_squared_error", cv=kf, verbose=10)
# ----> 7 grid_rfc.fit(X,y)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:729, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     727         estimator.fit(X_train, **fit_params)
#     728     else:
# --> 729         estimator.fit(X_train, y_train, **fit_params)
#     731 except Exception:
#     732     # Note fit time as time until error
#     733     fit_time = time.time() - start_time
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_forest.py:456, in BaseForest.fit(self, X, y, sample_weight)
#     445 trees = [
#     446     self._make_estimator(append=False, random_state=random_state)
#     447     for i in range(n_more_estimators)
#     448 ]
#     450 # Parallel loop: we prefer the threading backend as the Cython code
#     451 # for fitting the trees is internally releasing the Python GIL
#     452 # making threading more efficient than multiprocessing in
#     453 # that case. However, for joblib 0.12+ we respect any
#     454 # parallel_backend contexts set at a higher level,
#     455 # since correctness does not rely on using threads.
# --> 456 trees = Parallel(
#     457     n_jobs=self.n_jobs,
#     458     verbose=self.verbose,
#     459     prefer="threads",
#     460 )(
#     461     delayed(_parallel_build_trees)(
#     462         t,
#     463         self.bootstrap,
#     464         X,
#     465         y,
#     466         sample_weight,
#     467         i,
#     468         len(trees),
#     469         verbose=self.verbose,
#     470         class_weight=self.class_weight,
#     471         n_samples_bootstrap=n_samples_bootstrap,
#     472     )
#     473     for i, t in enumerate(trees)
#     474 )
#     476 # Collect newly grown trees
#     477 self.estimators_.extend(trees)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_forest.py:188, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     185     elif class_weight == "balanced_subsample":
#     186         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 188     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     189 else:
#     190     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\tree\_classes.py:1320, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1290 @_fit_context(prefer_skip_nested_validation=True)
#    1291 def fit(self, X, y, sample_weight=None, check_input=True):
#    1292     """Build a decision tree regressor from the training set (X, y).
#    1293
#    1294     Parameters
#    (...)
#    1317         Fitted estimator.
#    1318     """
# -> 1320     super()._fit(
#    1321         X,
#    1322         y,
#    1323         sample_weight=sample_weight,
#    1324         check_input=check_input,
#    1325     )
#    1326     return self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\tree\_classes.py:443, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     432 else:
#     433     builder = BestFirstTreeBuilder(
#     434         splitter,
#     435         min_samples_split,
#    (...)
#     440         self.min_impurity_decrease,
#     441     )
# --> 443 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     445 if self.n_outputs_ == 1 and is_classifier(self):
#     446     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
print(grid_rfc.best_score_)
print(grid_rfc.best_params_)

# %% [markdown]
# ##### Gradient Boosting Regressor

# %%
params = {
    "n_estimators": [100,500,1000],
    "max_depth": [2,4,6,8],
    "learning_rate": [0.1, 0.3]
}

grid_gbr = GridSearchCV(GradientBoostingRegressor(), params, scoring="neg_root_mean_squared_error", cv=kf, verbose=10)
grid_gbr.fit(X,y)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5; 1/24] START learning_rate=0.1, max_depth=2, n_estimators=100...........
# [CV 1/5; 1/24] END learning_rate=0.1, max_depth=2, n_estimators=100;, score=-34.978 total time= 2.4min
# [CV 2/5; 1/24] START learning_rate=0.1, max_depth=2, n_estimators=100...........
# [CV 2/5; 1/24] END learning_rate=0.1, max_depth=2, n_estimators=100;, score=-33.793 total time= 2.4min
# [CV 3/5; 1/24] START learning_rate=0.1, max_depth=2, n_estimators=100...........
# [CV 3/5; 1/24] END learning_rate=0.1, max_depth=2, n_estimators=100;, score=-37.758 total time= 2.3min
# [CV 4/5; 1/24] START learning_rate=0.1, max_depth=2, n_estimators=100...........
# [CV 4/5; 1/24] END learning_rate=0.1, max_depth=2, n_estimators=100;, score=-35.038 total time= 2.3min
# [CV 5/5; 1/24] START learning_rate=0.1, max_depth=2, n_estimators=100...........
# [CV 5/5; 1/24] END learning_rate=0.1, max_depth=2, n_estimators=100;, score=-36.598 total time= 2.3min
# [CV 1/5; 2/24] START learning_rate=0.1, max_depth=2, n_estimators=500...........
# [CV 1/5; 2/24] END learning_rate=0.1, max_depth=2, n_estimators=500;, score=-32.538 total time=11.1min
# [CV 2/5; 2/24] START learning_rate=0.1, max_depth=2, n_estimators=500...........
# [CV 2/5; 2/24] END learning_rate=0.1, max_depth=2, n_estimators=500;, score=-31.370 total time=10.1min
# [CV 3/5; 2/24] START learning_rate=0.1, max_depth=2, n_estimators=500...........
# [CV 3/5; 2/24] END learning_rate=0.1, max_depth=2, n_estimators=500;, score=-35.921 total time=10.8min
# [CV 4/5; 2/24] START learning_rate=0.1, max_depth=2, n_estimators=500...........
# [CV 4/5; 2/24] END learning_rate=0.1, max_depth=2, n_estimators=500;, score=-33.942 total time=11.1min
# [CV 5/5; 2/24] START learning_rate=0.1, max_depth=2, n_estimators=500...........
# [CV 5/5; 2/24] END learning_rate=0.1, max_depth=2, n_estimators=500;, score=-34.110 total time= 5.3min
# [CV 1/5; 3/24] START learning_rate=0.1, max_depth=2, n_estimators=1000..........
# [CV 1/5; 3/24] END learning_rate=0.1, max_depth=2, n_estimators=1000;, score=-31.676 total time=11.5min
# [CV 2/5; 3/24] START learning_rate=0.1, max_depth=2, n_estimators=1000..........
# [CV 2/5; 3/24] END learning_rate=0.1, max_depth=2, n_estimators=1000;, score=-30.660 total time=12.3min
# [CV 3/5; 3/24] START learning_rate=0.1, max_depth=2, n_estimators=1000..........
# [CV 3/5; 3/24] END learning_rate=0.1, max_depth=2, n_estimators=1000;, score=-35.152 total time=13.3min
# [CV 4/5; 3/24] START learning_rate=0.1, max_depth=2, n_estimators=1000..........
# [CV 4/5; 3/24] END learning_rate=0.1, max_depth=2, n_estimators=1000;, score=-33.071 total time=13.3min
# [CV 5/5; 3/24] START learning_rate=0.1, max_depth=2, n_estimators=1000..........
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[203], line 8
#       1 params = {
#       2     "n_estimators": [100,500,1000],
#       3     "max_depth": [2,4,6,8],
#       4     "learning_rate": [0.1, 0.3]
#       5 }
#       7 grid_gbr = GridSearchCV(GradientBoostingRegressor(), params, scoring="neg_root_mean_squared_error", cv=kf, verbose=10)
# ----> 8 grid_gbr.fit(X,y)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:729, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     727         estimator.fit(X_train, **fit_params)
#     728     else:
# --> 729         estimator.fit(X_train, y_train, **fit_params)
#     731 except Exception:
#     732     # Note fit time as time until error
#     733     fit_time = time.time() - start_time
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_gb.py:532, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     529     self._resize_state()
#     531 # fit the boosting stages
# --> 532 n_stages = self._fit_stages(
#     533     X_train,
#     534     y_train,
#     535     raw_predictions,
#     536     sample_weight_train,
#     537     self._rng,
#     538     X_val,
#     539     y_val,
#     540     sample_weight_val,
#     541     begin_at_stage,
#     542     monitor,
#     543 )
#     545 # change shape of arrays after fit (early-stopping or additional ests)
#     546 if n_stages != self.estimators_.shape[0]:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_gb.py:610, in BaseGradientBoosting._fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     603         initial_loss = loss_(
#     604             y[~sample_mask],
#     605             raw_predictions[~sample_mask],
#     606             sample_weight[~sample_mask],
#     607         )
#     609 # fit next stage of trees
# --> 610 raw_predictions = self._fit_stage(
#     611     i,
#     612     X,
#     613     y,
#     614     raw_predictions,
#     615     sample_weight,
#     616     sample_mask,
#     617     random_state,
#     618     X_csc,
#     619     X_csr,
#     620 )
#     622 # track loss
#     623 if do_oob:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_gb.py:245, in BaseGradientBoosting._fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     242     sample_weight = sample_weight * sample_mask.astype(np.float64)
#     244 X = X_csr if X_csr is not None else X
# --> 245 tree.fit(X, residual, sample_weight=sample_weight, check_input=False)
#     247 # update tree leaves
#     248 loss.update_terminal_regions(
#     249     tree.tree_,
#     250     X,
#    (...)
#     257     k=k,
#     258 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\tree\_classes.py:1320, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1290 @_fit_context(prefer_skip_nested_validation=True)
#    1291 def fit(self, X, y, sample_weight=None, check_input=True):
#    1292     """Build a decision tree regressor from the training set (X, y).
#    1293
#    1294     Parameters
#    (...)
#    1317         Fitted estimator.
#    1318     """
# -> 1320     super()._fit(
#    1321         X,
#    1322         y,
#    1323         sample_weight=sample_weight,
#    1324         check_input=check_input,
#    1325     )
#    1326     return self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\tree\_classes.py:443, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     432 else:
#     433     builder = BestFirstTreeBuilder(
#     434         splitter,
#     435         min_samples_split,
#    (...)
#     440         self.min_impurity_decrease,
#     441     )
# --> 443 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     445 if self.n_outputs_ == 1 and is_classifier(self):
#     446     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %% [markdown]
# ##### LGBMRegressor

# %%
params = {
    "n_estimators": [100,500,1000],
    "max_depth": [2,4,6,8],
    "learning_rate": [0.1, 0.3]
}

grid_lgbm = GridSearchCV(), params, scoring="neg_root_mean_squared_error", cv=kf, verbose=10)
grid_lgbm.fit(X,y)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5; 1/24] START learning_rate=0.1, max_depth=2, n_estimators=100...........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004870 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9932
# [LightGBM] [Info] Number of data points in the train set: 24445, number of used features: 40
# [LightGBM] [Info] Start training from score 61.051716
# [CV 1/5; 1/24] END learning_rate=0.1, max_depth=2, n_estimators=100;, score=-35.185 total time=   0.3s
# [CV 2/5; 1/24] START learning_rate=0.1, max_depth=2, n_estimators=100...........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007871 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9932
# [LightGBM] [Info] Number of data points in the train set: 24445, number of used features: 40
# [LightGBM] [Info] Start training from score 61.214641
# [CV 2/5; 1/24] END learning_rate=0.1, max_depth=2, n_estimators=100;, score=-33.643 total time=   0.3s
# [CV 3/5; 1/24] START learning_rate=0.1, max_depth=2, n_estimators=100...........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004403 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9931
# [LightGBM] [Info] Number of data points in the train set: 24446, number of used features: 40
# [LightGBM] [Info] Start training from score 61.251051
# [CV 3/5; 1/24] END learning_rate=0.1, max_depth=2, n_estimators=100;, score=-37.313 total time=   0.3s
# [CV 4/5; 1/24] START learning_rate=0.1, max_depth=2, n_estimators=100...........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004651 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9933
# [LightGBM] [Info] Number of data points in the train set: 24446, number of used features: 40
# [LightGBM] [Info] Start training from score 61.195881
# [CV 4/5; 1/24] END learning_rate=0.1, max_depth=2, n_estimators=100;, score=-34.822 total time=   0.2s
# [CV 5/5; 1/24] START learning_rate=0.1, max_depth=2, n_estimators=100...........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007767 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9932
# [LightGBM] [Info] Number of data points in the train set: 24446, number of used features: 40
# [LightGBM] [Info] Start training from score 61.026933
# [CV 5/5; 1/24] END learning_rate=0.1, max_depth=2, n_estimators=100;, score=-36.562 total time=   0.3s
# [CV 1/5; 2/24] START learning_rate=0.1, max_depth=2, n_estimators=500...........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007888 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9932
# [LightGBM] [Info] Number of data points in the train set: 24445, number of used features: 40
# [LightGBM] [Info] Start training from score 61.051716
# [CV 1/5; 2/24] END learning_rate=0.1, max_depth=2, n_estimators=500;, score=-32.588 total time=   1.0s
# [CV 2/5; 2/24] START learning_rate=0.1, max_depth=2, n_estimators=500...........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005207 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9932
# [LightGBM] [Info] Number of data points in the train set: 24445, number of used features: 40
# [LightGBM] [Info] Start training from score 61.214641
# [CV 2/5; 2/24] END learning_rate=0.1, max_depth=2, n_estimators=500;, score=-31.132 total time=   1.0s
# [CV 3/5; 2/24] START learning_rate=0.1, max_depth=2, n_estimators=500...........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008130 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9931
# [LightGBM] [Info] Number of data points in the train set: 24446, number of used features: 40
# [LightGBM] [Info] Start training from score 61.251051
# [CV 3/5; 2/24] END learning_rate=0.1, max_depth=2, n_estimators=500;, score=-35.212 total time=   1.0s
# [CV 4/5; 2/24] START learning_rate=0.1, max_depth=2, n_estimators=500...........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008311 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9933
# [LightGBM] [Info] Number of data points in the train set: 24446, number of used features: 40
# [LightGBM] [Info] Start training from score 61.195881
# [CV 4/5; 2/24] END learning_rate=0.1, max_depth=2, n_estimators=500;, score=-32.461 total time=   1.0s
# [CV 5/5; 2/24] START learning_rate=0.1, max_depth=2, n_estimators=500...........
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001743 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9932
# [LightGBM] [Info] Number of data points in the train set: 24446, number of used features: 40
# [LightGBM] [Info] Start training from score 61.026933
# [CV 5/5; 2/24] END learning_rate=0.1, max_depth=2, n_estimators=500;, score=-33.757 total time=   1.0s
# [CV 1/5; 3/24] START learning_rate=0.1, max_depth=2, n_estimators=1000..........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006580 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9932
# [LightGBM] [Info] Number of data points in the train set: 24445, number of used features: 40
# [LightGBM] [Info] Start training from score 61.051716
# [CV 1/5; 3/24] END learning_rate=0.1, max_depth=2, n_estimators=1000;, score=-31.677 total time=   1.8s
# [CV 2/5; 3/24] START learning_rate=0.1, max_depth=2, n_estimators=1000..........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006349 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9932
# [LightGBM] [Info] Number of data points in the train set: 24445, number of used features: 40
# [LightGBM] [Info] Start training from score 61.214641
# [CV 2/5; 3/24] END learning_rate=0.1, max_depth=2, n_estimators=1000;, score=-30.363 total time=   1.7s
# [CV 3/5; 3/24] START learning_rate=0.1, max_depth=2, n_estimators=1000..........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005038 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9931
# [LightGBM] [Info] Number of data points in the train set: 24446, number of used features: 40
# [LightGBM] [Info] Start training from score 61.251051
# [CV 3/5; 3/24] END learning_rate=0.1, max_depth=2, n_estimators=1000;, score=-34.506 total time=   1.7s
# [CV 4/5; 3/24] START learning_rate=0.1, max_depth=2, n_estimators=1000..........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005263 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9933
# [LightGBM] [Info] Number of data points in the train set: 24446, number of used features: 40
# [LightGBM] [Info] Start training from score 61.195881
# [CV 4/5; 3/24] END learning_rate=0.1, max_depth=2, n_estimators=1000;, score=-31.528 total time=   1.6s
# [CV 5/5; 3/24] START learning_rate=0.1, max_depth=2, n_estimators=1000..........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005362 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9932
# [LightGBM] [Info] Number of data points in the train set: 24446, number of used features: 40
# [LightGBM] [Info] Start training from score 61.026933
# [CV 5/5; 3/24] END learning_rate=0.1, max_depth=2, n_estimators=1000;, score=-32.746 total time=   1.6s
# [CV 1/5; 4/24] START learning_rate=0.1, max_depth=4, n_estimators=100...........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007768 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9932
# [LightGBM] [Info] Number of data points in the train set: 24445, number of used features: 40
# [LightGBM] [Info] Start training from score 61.051716
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 1/5; 4/24] END learning_rate=0.1, max_depth=4, n_estimators=100;, score=-32.212 total time=   0.4s
# [CV 2/5; 4/24] START learning_rate=0.1, max_depth=4, n_estimators=100...........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004441 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9932
# [LightGBM] [Info] Number of data points in the train set: 24445, number of used features: 40
# [LightGBM] [Info] Start training from score 61.214641
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 2/5; 4/24] END learning_rate=0.1, max_depth=4, n_estimators=100;, score=-30.836 total time=   0.3s
# [CV 3/5; 4/24] START learning_rate=0.1, max_depth=4, n_estimators=100...........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005974 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9931
# [LightGBM] [Info] Number of data points in the train set: 24446, number of used features: 40
# [LightGBM] [Info] Start training from score 61.251051
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 3/5; 4/24] END learning_rate=0.1, max_depth=4, n_estimators=100;, score=-34.833 total time=   0.3s
# [CV 4/5; 4/24] START learning_rate=0.1, max_depth=4, n_estimators=100...........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004363 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9933
# [LightGBM] [Info] Number of data points in the train set: 24446, number of used features: 40
# [LightGBM] [Info] Start training from score 61.195881
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 4/5; 4/24] END learning_rate=0.1, max_depth=4, n_estimators=100;, score=-32.182 total time=   0.4s
# [CV 5/5; 4/24] START learning_rate=0.1, max_depth=4, n_estimators=100...........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005005 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9932
# [LightGBM] [Info] Number of data points in the train set: 24446, number of used features: 40
# [LightGBM] [Info] Start training from score 61.026933
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 5/5; 4/24] END learning_rate=0.1, max_depth=4, n_estimators=100;, score=-33.412 total time=   0.3s
# [CV 1/5; 5/24] START learning_rate=0.1, max_depth=4, n_estimators=500...........
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007118 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9932
# [LightGBM] [Info] Number of data points in the train set: 24445, number of used features: 40
# [LightGBM] [Info] Start training from score 61.051716
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [CV 5/5; 24/24] END learning_rate=0.3, max_depth=8, n_estimators=1000;, score=-30.151 total time=  15.7s
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.014717 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9933
# [LightGBM] [Info] Number of data points in the train set: 30557, number of used features: 40
# [LightGBM] [Info] Start training from score 61.148045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
print(grid_lgbm.best_score_)
print(grid_lgbm.best_params_)

# -28.3730333187195
# {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 1000}
# Out:
# -28.17436203370791
# {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 1000}

# %% [markdown]
# ### Predicting

# %%
ids = processed_test_df["Place_ID X Date"]

X_test = scaler.transform(processed_test_df.drop(["Place_ID X Date", "Place_ID"], axis=1))
preds = grid_lgbm.predict(X_test)

# %%
submission = pd.DataFrame({"Place_ID X Date": ids, "target": preds})

# %%
import os

# %%
# if not os.path.exists("x__submissions"):
#     os.mkdir("x__submissions")

# save_name="submission_lgbm2.csv"
# submission.to_csv(f"x__submissions/{save_name}", index=False)

# %% [markdown]
# ## To Explore
# - combinations
