# %% [markdown]
# # Fraud Detection in Electricity and Gas Consumption Challenge
#
# This challenge is meant to ....

# %% [markdown]
# ### Importing necessary packages for data handling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Getting data

# %%
train_path = "x__data/train"
test_path = "x__data/test"


client_train = pd.read_csv(f"{train_path}/client_train.csv")
invoice_train = pd.read_csv(f"{train_path}/invoice_train.csv")

client_test = pd.read_csv(f"{test_path}/client_test.csv")
invoice_test = pd.read_csv(f"{test_path}/invoice_test.csv")
# Out:
# C:\Users\Eli\AppData\Local\Temp\ipykernel_3904\2974162188.py:6: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   invoice_train = pd.read_csv(f"{train_path}/invoice_train.csv")

# %%
d = {"ELEC":0, "GAZ":1}
invoice_train["counter_type"] = invoice_train["counter_type"].map(d)
invoice_test["counter_type"] = invoice_test["counter_type"].map(d)

# %%
invoice_test
# Out:
#                 client_id invoice_date  tarif_type  counter_number  \
# 0           test_Client_0   2018-03-16          11          651208
# 1           test_Client_0   2014-03-21          11          651208
# 2           test_Client_0   2014-07-17          11          651208
# 3           test_Client_0   2015-07-13          11          651208
# 4           test_Client_0   2016-07-19          11          651208
# ...                   ...          ...         ...             ...
# 1939725  test_Client_9999   2010-03-11          11          869269
# 1939726  test_Client_9999   2011-03-15          11          869269
# 1939727  test_Client_9999   2012-12-03          11          869269
# 1939728  test_Client_9999   2009-07-01          11          869269
# 1939729  test_Client_9999   2017-03-11          11          869269
#
#          counter_statue  counter_code  reading_remarque  counter_coefficient  \
# 0                     0           203                 8                    1
# 1                     0           203                 8                    1
# 2                     0           203                 8                    1
# 3                     0           203                 9                    1
# 4                     0           203                 9                    1
# ...                 ...           ...               ...                  ...
# 1939725               0           203                 6                    1
# 1939726               0           203                 6                    1
# 1939727               0           203                 6                    1
# 1939728               0           203                 6                    1
# 1939729               0           203                 9                    1
#
#          consommation_level_1  consommation_level_2  consommation_level_3  \
# 0                         755                     0                     0
# 1                        1067                     0                     0
# 2                           0                     0                     0
# 3                         410                     0                     0
# 4                         412                     0                     0
# ...                       ...                   ...                   ...
# 1939725                   248                     0                     0
# 1939726                   260                     0                     0
# 1939727                   312                     0                     0
# 1939728                   236                     0                     0
# 1939729                   800                   282                     0
#
#          consommation_level_4  old_index  new_index  months_number  \
# 0                           0      19145      19900              8
# 1                           0      13725      14792              8
# 2                           0      14792      14792              4
# 3                           0      16122      16532              4
# 4                           0      17471      17883              4
# ...                       ...        ...        ...            ...
# 1939725                     0      21114      21362              4
# 1939726                     0      21362      21622              4
# 1939727                     0      22272      22584              4
# 1939728                     0      19909      20145              4
# 1939729                     0      32834      33916              4
#
#          counter_type
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 1939725             0
# 1939726             0
# 1939727             0
# 1939728             0
# 1939729             0
#
# [1939730 rows x 16 columns]

# %% [markdown]
# ### EDA

# %% [markdown]
# #### Checking the features

# %%
client_train.dtypes
# Out:
# disrict            int64
# client_id         object
# client_catg        int64
# region             int64
# creation_date     object
# target           float64
# dtype: object

# %%
invoice_train.dtypes
# Out:
# client_id               object
# invoice_date            object
# tarif_type               int64
# counter_number           int64
# counter_statue          object
# counter_code             int64
# reading_remarque         int64
# counter_coefficient      int64
# consommation_level_1     int64
# consommation_level_2     int64
# consommation_level_3     int64
# consommation_level_4     int64
# old_index                int64
# new_index                int64
# months_number            int64
# counter_type             int64
# dtype: object

# %% [markdown]
# #### Inspecting Client data

# %%
sns.displot(client_train["disrict"])
plt.show()

# %%
sns.displot(client_train, x="disrict", hue="target")
plt.show()

# %%
fig, ax = plt.subplots()
sns.countplot(client_train, x="client_catg", ax=ax)
ax.set_yscale("log")
plt.show()

# %%
fig, ax = plt.subplots()
sns.countplot(client_train, x="client_catg", ax=ax, hue="target")
ax.set_yscale("log")
plt.show()

# %%
fig, ax = plt.subplots()
sns.countplot(client_train, x="region", ax=ax, hue="target")
# ax.set_yscale("log")
# ax.xticks(rotation=90)
plt.xticks(rotation=90)
plt.show()

# %%
client_train["target"].value_counts(normalize=True)
# Out:
# target
# 0.0    0.944159
# 1.0    0.055841
# Name: proportion, dtype: float64

# %%
sns.pairplot(client_train.select_dtypes("number"), hue="target")
plt.show()

# %% [markdown]
# #### Inspecting Invoice Data

# %%
invoice_train.describe()
# Out:
#          tarif_type  counter_number  counter_code  reading_remarque  \
# count  4.476749e+06    4.476749e+06  4.476749e+06      4.476749e+06
# mean   2.012804e+01    1.230587e+11  1.724884e+02      7.321702e+00
# std    1.347256e+01    1.657267e+12  1.338871e+02      1.571654e+00
# min    8.000000e+00    0.000000e+00  0.000000e+00      5.000000e+00
# 25%    1.100000e+01    1.211080e+05  5.000000e+00      6.000000e+00
# 50%    1.100000e+01    4.945610e+05  2.030000e+02      8.000000e+00
# 75%    4.000000e+01    1.115161e+06  2.070000e+02      9.000000e+00
# max    4.500000e+01    2.798115e+13  6.000000e+02      4.130000e+02
#
#        counter_coefficient  consommation_level_1  consommation_level_2  \
# count         4.476749e+06          4.476749e+06          4.476749e+06
# mean          1.003040e+00          4.109795e+02          1.093225e+02
# std           3.083466e-01          7.573080e+02          1.220123e+03
# min           0.000000e+00          0.000000e+00          0.000000e+00
# 25%           1.000000e+00          7.900000e+01          0.000000e+00
# 50%           1.000000e+00          2.740000e+02          0.000000e+00
# 75%           1.000000e+00          6.000000e+02          0.000000e+00
# max           5.000000e+01          9.999100e+05          9.990730e+05
#
#        consommation_level_3  consommation_level_4     old_index     new_index  \
# count          4.476749e+06          4.476749e+06  4.476749e+06  4.476749e+06
# mean           2.030620e+01          5.292588e+01  1.776700e+04  1.834970e+04
# std            1.574239e+02          8.754725e+02  4.036693e+04  4.095321e+04
# min            0.000000e+00          0.000000e+00  0.000000e+00  0.000000e+00
# 25%            0.000000e+00          0.000000e+00  1.791000e+03  2.056000e+03
# 50%            0.000000e+00          0.000000e+00  7.690000e+03  8.192000e+03
# 75%            0.000000e+00          0.000000e+00  2.166000e+04  2.234300e+04
# max            6.449200e+04          5.479460e+05  2.800280e+06  2.870972e+06
#
#        months_number  counter_type
# count   4.476749e+06  4.476749e+06
# mean    4.483095e+01  3.121334e-01
# std     3.128335e+03  4.633640e-01
# min     0.000000e+00  0.000000e+00
# 25%     4.000000e+00  0.000000e+00
# 50%     4.000000e+00  0.000000e+00
# 75%     4.000000e+00  1.000000e+00
# max     6.366240e+05  1.000000e+00

# %% [markdown]
# ##### Taking a look at what the invoice data of a non-fraudulent looks like

# %%
non_fraud_ids = client_train[client_train["target"]==0]["client_id"]
fraud_ids = client_train[client_train["target"]==1]["client_id"]

# %%
normal = non_fraud_ids.sample(1).values[0]
fraudster = fraud_ids.sample(1).values[0]

# %%
invoice_train[invoice_train["client_id"]==normal].sort_values("invoice_date").describe()
# Out:
#        tarif_type  counter_number  counter_code  reading_remarque  \
# count   41.000000       41.000000     41.000000          41.00000
# mean    19.487805   134285.560976    145.048780           7.00000
# std     13.358746    87454.643654     91.207991           1.30384
# min     11.000000        0.000000      5.000000           6.00000
# 25%     11.000000        0.000000      5.000000           6.00000
# 50%     11.000000   189852.000000    203.000000           6.00000
# 75%     40.000000   189852.000000    203.000000           8.00000
# max     40.000000   189852.000000    203.000000           9.00000
#
#        counter_coefficient  consommation_level_1  consommation_level_2  \
# count                 41.0             41.000000                  41.0
# mean                   1.0            175.804878                   0.0
# std                    0.0            196.140666                   0.0
# min                    1.0              0.000000                   0.0
# 25%                    1.0              0.000000                   0.0
# 50%                    1.0            180.000000                   0.0
# 75%                    1.0            334.000000                   0.0
# max                    1.0            651.000000                   0.0
#
#        consommation_level_3  consommation_level_4    old_index    new_index  \
# count                  41.0                  41.0    41.000000    41.000000
# mean                    0.0                   0.0  2984.341463  3160.146341
# std                     0.0                   0.0  2730.681853  2765.550267
# min                     0.0                   0.0     0.000000     0.000000
# 25%                     0.0                   0.0     0.000000     0.000000
# 50%                     0.0                   0.0  3106.000000  3375.000000
# 75%                     0.0                   0.0  5313.000000  5528.000000
# max                     0.0                   0.0  7208.000000  7208.000000
#
#        months_number  counter_type
# count      41.000000     41.000000
# mean        3.951220      0.292683
# std         0.312348      0.460646
# min         2.000000      0.000000
# 25%         4.000000      0.000000
# 50%         4.000000      0.000000
# 75%         4.000000      1.000000
# max         4.000000      1.000000

# %%
invoice_train[invoice_train["client_id"]==fraudster].sort_values("invoice_date").describe()
# Out:
#        tarif_type  counter_number  counter_code  reading_remarque  \
# count        43.0            43.0          43.0         43.000000
# mean         11.0         64823.0         203.0          6.325581
# std           0.0             0.0           0.0          0.747087
# min          11.0         64823.0         203.0          6.000000
# 25%          11.0         64823.0         203.0          6.000000
# 50%          11.0         64823.0         203.0          6.000000
# 75%          11.0         64823.0         203.0          6.000000
# max          11.0         64823.0         203.0          8.000000
#
#        counter_coefficient  consommation_level_1  consommation_level_2  \
# count                 43.0             43.000000                  43.0
# mean                   1.0            203.046512                   0.0
# std                    0.0             79.835233                   0.0
# min                    1.0             62.000000                   0.0
# 25%                    1.0            144.500000                   0.0
# 50%                    1.0            196.000000                   0.0
# 75%                    1.0            263.000000                   0.0
# max                    1.0            367.000000                   0.0
#
#        consommation_level_3  consommation_level_4     old_index     new_index  \
# count                  43.0                  43.0     43.000000     43.000000
# mean                    0.0                   0.0  28274.372093  28477.418605
# std                     0.0                   0.0   2472.813676   2503.484897
# min                     0.0                   0.0  24244.000000  24508.000000
# 25%                     0.0                   0.0  26436.500000  26572.500000
# 50%                     0.0                   0.0  27924.000000  28211.000000
# 75%                     0.0                   0.0  30378.000000  30475.000000
# max                     0.0                   0.0  32972.000000  33325.000000
#
#        months_number  counter_type
# count      43.000000          43.0
# mean        3.906977           0.0
# std         0.426165           0.0
# min         2.000000           0.0
# 25%         4.000000           0.0
# 50%         4.000000           0.0
# 75%         4.000000           0.0
# max         4.000000           0.0

# %%
def process_data(client, invoice, num_cols):
    invoice_grouped = invoice.groupby("client_id")[num_cols].agg(["mean", "std", "sum"])
    
    series = []
    for col_a, col_b in invoice_grouped.columns:
        new_col = f"{col_a}_{col_b}"
        item = invoice_grouped[col_a, col_b].rename(new_col)
        if col_b == "std":
            item = item.fillna(0) ## fill with zero for clients who only have one entry in the invoice dataset
        series.append(item)
    
    inv_df = pd.concat(series, axis=1)
    full_df = pd.concat([inv_df, client.set_index("client_id")], axis=1)

    cols_to_drop=["tarif_type", "old_index"]
    
    for col in cols_to_drop:
        full_df.drop([f"{col}_mean", f"{col}_std", f"{col}_sum"], axis=1, inplace=True)

    full_df.drop("creation_date", axis=1, inplace=True)

    return full_df

# %%
num_cols = list(invoice_train.select_dtypes("number").columns)

invoice_train_grouped = invoice_train.groupby("client_id")[num_cols].agg(["mean", "std", "sum"])

# %%
invoice_train_grouped.columns
# Out:
# MultiIndex([(          'tarif_type', 'mean'),
#             (          'tarif_type',  'std'),
#             (          'tarif_type',  'sum'),
#             (      'counter_number', 'mean'),
#             (      'counter_number',  'std'),
#             (      'counter_number',  'sum'),
#             (        'counter_code', 'mean'),
#             (        'counter_code',  'std'),
#             (        'counter_code',  'sum'),
#             (    'reading_remarque', 'mean'),
#             (    'reading_remarque',  'std'),
#             (    'reading_remarque',  'sum'),
#             ( 'counter_coefficient', 'mean'),
#             ( 'counter_coefficient',  'std'),
#             ( 'counter_coefficient',  'sum'),
#             ('consommation_level_1', 'mean'),
#             ('consommation_level_1',  'std'),
#             ('consommation_level_1',  'sum'),
#             ('consommation_level_2', 'mean'),
#             ('consommation_level_2',  'std'),
#             ('consommation_level_2',  'sum'),
#             ('consommation_level_3', 'mean'),
#             ('consommation_level_3',  'std'),
#             ('consommation_level_3',  'sum'),
#             ('consommation_level_4', 'mean'),
#             ('consommation_level_4',  'std'),
#             ('consommation_level_4',  'sum'),
#             (           'old_index', 'mean'),
#             (           'old_index',  'std'),
#             (           'old_index',  'sum'),
#             (           'new_index', 'mean'),
#             (           'new_index',  'std'),
#             (           'new_index',  'sum'),
#             (       'months_number', 'mean'),
#             (       'months_number',  'std'),
#             (       'months_number',  'sum'),
#             (        'counter_type', 'mean'),
#             (        'counter_type',  'std'),
#             (        'counter_type',  'sum')],
#            )

# %%
series = []
for col_a, col_b in invoice_train_grouped.columns:
    new_col = f"{col_a}_{col_b}"
    item = invoice_train_grouped[col_a, col_b].rename(new_col)
    if col_b == "std":
        item = item.fillna(0) ## fill with zero for clients who only have one entry in the invoice dataset
    series.append(item)

inv_df = pd.concat(series, axis=1)

# %%
full_train_df = pd.concat([inv_df, client_train.set_index("client_id")], axis=1)

# %%
full_train_df.isna().sum()
# Out:
# tarif_type_mean              0
# tarif_type_std               0
# tarif_type_sum               0
# counter_number_mean          0
# counter_number_std           0
# counter_number_sum           0
# counter_code_mean            0
# counter_code_std             0
# counter_code_sum             0
# reading_remarque_mean        0
# reading_remarque_std         0
# reading_remarque_sum         0
# counter_coefficient_mean     0
# counter_coefficient_std      0
# counter_coefficient_sum      0
# consommation_level_1_mean    0
# consommation_level_1_std     0
# consommation_level_1_sum     0
# consommation_level_2_mean    0
# consommation_level_2_std     0
# consommation_level_2_sum     0
# consommation_level_3_mean    0
# consommation_level_3_std     0
# consommation_level_3_sum     0
# consommation_level_4_mean    0
# consommation_level_4_std     0
# consommation_level_4_sum     0
# old_index_mean               0
# old_index_std                0
# old_index_sum                0
# new_index_mean               0
# new_index_std                0
# new_index_sum                0
# months_number_mean           0
# months_number_std            0
# months_number_sum            0
# counter_type_mean            0
# counter_type_std             0
# counter_type_sum             0
# disrict                      0
# client_catg                  0
# region                       0
# creation_date                0
# target                       0
# dtype: int64

# %%
invoice_train_grouped["tarif_type", "std"][np.isnan(invoice_train_grouped["tarif_type", "std"])].index[9]
# Out:
# 'train_Client_100250'

# %%
invoice_train[invoice_train["client_id"]=='train_Client_100018']
# Out:
#                client_id invoice_date  tarif_type  counter_number  \
# 854  train_Client_100018   2019-05-03          11   2178700025696
#
#     counter_statue  counter_code  reading_remarque  counter_coefficient  \
# 854              0           413                 8                    1
#
#      consommation_level_1  consommation_level_2  consommation_level_3  \
# 854                   600                   300                   325
#
#      consommation_level_4  old_index  new_index  months_number  counter_type
# 854                     0       4865       6090              3             0

# %%
# Out:
# tarif_type_mean                    10.0
# tarif_type_std                      0.0
# tarif_type_sum                       10
# counter_number_mean            510124.0
# counter_number_std                  0.0
# counter_number_sum               510124
# counter_code_mean                 202.0
# counter_code_std                    0.0
# counter_code_sum                    202
# reading_remarque_mean               7.0
# reading_remarque_std                0.0
# reading_remarque_sum                  7
# counter_coefficient_mean            1.0
# counter_coefficient_std             0.0
# counter_coefficient_sum               1
# consommation_level_1_mean         100.0
# consommation_level_1_std            0.0
# consommation_level_1_sum            100
# consommation_level_2_mean          39.0
# consommation_level_2_std            0.0
# consommation_level_2_sum             39
# consommation_level_3_mean           0.0
# consommation_level_3_std            0.0
# consommation_level_3_sum              0
# consommation_level_4_mean           0.0
# consommation_level_4_std            0.0
# consommation_level_4_sum              0
# old_index_mean                  15113.0
# old_index_std                       0.0
# old_index_sum                     15113
# new_index_mean                  15252.0
# new_index_std                       0.0
# new_index_sum                     15252
# months_number_mean                  2.0
# months_number_std                   0.0
# months_number_sum                     2
# counter_type_mean                   0.0
# counter_type_std                    0.0
# counter_type_sum                      0
# disrict                              62
# client_catg                          11
# region                              304
# creation_date                18/01/1993
# target                              0.0
# Name: train_Client_100250, dtype: object

# %%
full_train_df
# Out:
#                     tarif_type_mean  tarif_type_std  tarif_type_sum  \
# client_id
# train_Client_0            11.000000        0.000000             385
# train_Client_1            11.000000        0.000000             407
# train_Client_10           11.000000        0.000000             198
# train_Client_100          11.000000        0.000000             220
# train_Client_1000         11.000000        0.000000             154
# ...                             ...             ...             ...
# train_Client_99995        24.887324       14.590162            1767
# train_Client_99996        25.853659       14.675764            1060
# train_Client_99997        22.277778       14.337984             802
# train_Client_99998        10.000000        0.000000              20
# train_Client_99999        11.000000        0.000000              33
#
#                     counter_number_mean  counter_number_std  \
# client_id
# train_Client_0             1.335667e+06        0.000000e+00
# train_Client_1             6.789020e+05        0.000000e+00
# train_Client_10            5.727650e+05        0.000000e+00
# train_Client_100           2.078000e+03        0.000000e+00
# train_Client_1000          1.957500e+04        0.000000e+00
# ...                                 ...                 ...
# train_Client_99995         5.423355e+05        3.729146e+05
# train_Client_99996         1.837554e+06        2.172997e+06
# train_Client_99997         1.602303e+05        1.296327e+05
# train_Client_99998         1.253571e+06        0.000000e+00
# train_Client_99999         5.609480e+05        0.000000e+00
#
#                     counter_number_sum  counter_code_mean  counter_code_std  \
# client_id
# train_Client_0                46748345         203.685714          1.529541
# train_Client_1                25119374         203.000000          0.000000
# train_Client_10               10309770         203.222222          0.942809
# train_Client_100                 41560         413.000000          0.000000
# train_Client_1000               274050         207.000000          0.000000
# ...                                ...                ...               ...
# train_Client_99995            38505820         110.267606        101.628027
# train_Client_99996            75339726         103.536585        102.224287
# train_Client_99997             5768290         128.444444         99.871473
# train_Client_99998             2507142         202.000000          0.000000
# train_Client_99999             1682844         203.000000          0.000000
#
#                     counter_code_sum  reading_remarque_mean  ...  \
# client_id                                                    ...
# train_Client_0                  7129               6.971429  ...
# train_Client_1                  7511               7.216216  ...
# train_Client_10                 3658               7.055556  ...
# train_Client_100                8260               6.150000  ...
# train_Client_1000               2898               8.857143  ...
# ...                              ...                    ...  ...
# train_Client_99995              7829               6.000000  ...
# train_Client_99996              4245               8.487805  ...
# train_Client_99997              4624               9.000000  ...
# train_Client_99998               404               7.500000  ...
# train_Client_99999               609               6.000000  ...
#
#                     months_number_std  months_number_sum  counter_type_mean  \
# client_id
# train_Client_0               2.101620                162           0.000000
# train_Client_1               1.375461                160           0.000000
# train_Client_10              3.399346                116           0.000000
# train_Client_100             0.615587                 84           0.000000
# train_Client_1000            0.726273                 52           0.000000
# ...                               ...                ...                ...
# train_Client_99995           1.098014                300           0.478873
# train_Client_99996           0.436170                160           0.512195
# train_Client_99997           0.666667                148           0.388889
# train_Client_99998           2.828427                 12           0.000000
# train_Client_99999           0.000000                 12           0.000000
#
#                     counter_type_std  counter_type_sum  disrict  client_catg  \
# client_id
# train_Client_0              0.000000                 0       60           11
# train_Client_1              0.000000                 0       69           11
# train_Client_10             0.000000                 0       62           11
# train_Client_100            0.000000                 0       69           11
# train_Client_1000           0.000000                 0       62           11
# ...                              ...               ...      ...          ...
# train_Client_99995          0.503109                34       62           11
# train_Client_99996          0.506061                21       63           11
# train_Client_99997          0.494413                14       63           11
# train_Client_99998          0.000000                 0       60           11
# train_Client_99999          0.000000                 0       60           11
#
#                     region  creation_date  target
# client_id
# train_Client_0         101     31/12/1994     0.0
# train_Client_1         107     29/05/2002     0.0
# train_Client_10        301     13/03/1986     0.0
# train_Client_100       105     11/07/1996     0.0
# train_Client_1000      303     14/10/2014     0.0
# ...                    ...            ...     ...
# train_Client_99995     304     26/07/2004     0.0
# train_Client_99996     311     25/10/2012     0.0
# train_Client_99997     311     22/11/2011     0.0
# train_Client_99998     101     22/12/1993     0.0
# train_Client_99999     101     18/02/1986     0.0
#
# [135493 rows x 44 columns]

# %%
fig = plt.figure(figsize=(12,12))
g = sns.heatmap(full_train_df.select_dtypes("number").corr(), annot=True, fmt=".1f", square=True, cbar=False)
g.set_xticklabels(labels=g.get_xmajorticklabels(),fontsize=5)
g.set_yticklabels(labels=g.get_ymajorticklabels(),fontsize=5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Insights
# - seems the `tarif_type` is highly correlated with `counter_type`
# - seems the `old_index` is highly correlated with `new_index`

# %%
cols_to_drop=["tarif_type", "old_index"]

for col in cols_to_drop:
    full_train_df.drop([f"{col}_mean", f"{col}_std", f"{col}_sum"], axis=1, inplace=True)

# %%
full_train_df
# Out:
#                     counter_number_mean  counter_number_std  \
# client_id
# train_Client_0             1.335667e+06        0.000000e+00
# train_Client_1             6.789020e+05        0.000000e+00
# train_Client_10            5.727650e+05        0.000000e+00
# train_Client_100           2.078000e+03        0.000000e+00
# train_Client_1000          1.957500e+04        0.000000e+00
# ...                                 ...                 ...
# train_Client_99995         5.423355e+05        3.729146e+05
# train_Client_99996         1.837554e+06        2.172997e+06
# train_Client_99997         1.602303e+05        1.296327e+05
# train_Client_99998         1.253571e+06        0.000000e+00
# train_Client_99999         5.609480e+05        0.000000e+00
#
#                     counter_number_sum  counter_code_mean  counter_code_std  \
# client_id
# train_Client_0                46748345         203.685714          1.529541
# train_Client_1                25119374         203.000000          0.000000
# train_Client_10               10309770         203.222222          0.942809
# train_Client_100                 41560         413.000000          0.000000
# train_Client_1000               274050         207.000000          0.000000
# ...                                ...                ...               ...
# train_Client_99995            38505820         110.267606        101.628027
# train_Client_99996            75339726         103.536585        102.224287
# train_Client_99997             5768290         128.444444         99.871473
# train_Client_99998             2507142         202.000000          0.000000
# train_Client_99999             1682844         203.000000          0.000000
#
#                     counter_code_sum  reading_remarque_mean  \
# client_id
# train_Client_0                  7129               6.971429
# train_Client_1                  7511               7.216216
# train_Client_10                 3658               7.055556
# train_Client_100                8260               6.150000
# train_Client_1000               2898               8.857143
# ...                              ...                    ...
# train_Client_99995              7829               6.000000
# train_Client_99996              4245               8.487805
# train_Client_99997              4624               9.000000
# train_Client_99998               404               7.500000
# train_Client_99999               609               6.000000
#
#                     reading_remarque_std  reading_remarque_sum  \
# client_id
# train_Client_0                  1.248192                   244
# train_Client_1                  1.377097                   267
# train_Client_10                 1.258955                   127
# train_Client_100                0.670820                   123
# train_Client_1000               0.363137                   124
# ...                                  ...                   ...
# train_Client_99995              0.000000                   426
# train_Client_99996              1.142846                   348
# train_Client_99997              0.000000                   324
# train_Client_99998              2.121320                    15
# train_Client_99999              0.000000                    18
#
#                     counter_coefficient_mean  ...  months_number_std  \
# client_id                                     ...
# train_Client_0                           1.0  ...           2.101620
# train_Client_1                           1.0  ...           1.375461
# train_Client_10                          1.0  ...           3.399346
# train_Client_100                         1.0  ...           0.615587
# train_Client_1000                        1.0  ...           0.726273
# ...                                      ...  ...                ...
# train_Client_99995                       1.0  ...           1.098014
# train_Client_99996                       1.0  ...           0.436170
# train_Client_99997                       1.0  ...           0.666667
# train_Client_99998                       1.0  ...           2.828427
# train_Client_99999                       1.0  ...           0.000000
#
#                     months_number_sum  counter_type_mean  counter_type_std  \
# client_id
# train_Client_0                    162           0.000000          0.000000
# train_Client_1                    160           0.000000          0.000000
# train_Client_10                   116           0.000000          0.000000
# train_Client_100                   84           0.000000          0.000000
# train_Client_1000                  52           0.000000          0.000000
# ...                               ...                ...               ...
# train_Client_99995                300           0.478873          0.503109
# train_Client_99996                160           0.512195          0.506061
# train_Client_99997                148           0.388889          0.494413
# train_Client_99998                 12           0.000000          0.000000
# train_Client_99999                 12           0.000000          0.000000
#
#                     counter_type_sum  disrict  client_catg  region  \
# client_id
# train_Client_0                     0       60           11     101
# train_Client_1                     0       69           11     107
# train_Client_10                    0       62           11     301
# train_Client_100                   0       69           11     105
# train_Client_1000                  0       62           11     303
# ...                              ...      ...          ...     ...
# train_Client_99995                34       62           11     304
# train_Client_99996                21       63           11     311
# train_Client_99997                14       63           11     311
# train_Client_99998                 0       60           11     101
# train_Client_99999                 0       60           11     101
#
#                     creation_date  target
# client_id
# train_Client_0         31/12/1994     0.0
# train_Client_1         29/05/2002     0.0
# train_Client_10        13/03/1986     0.0
# train_Client_100       11/07/1996     0.0
# train_Client_1000      14/10/2014     0.0
# ...                           ...     ...
# train_Client_99995     26/07/2004     0.0
# train_Client_99996     25/10/2012     0.0
# train_Client_99997     22/11/2011     0.0
# train_Client_99998     22/12/1993     0.0
# train_Client_99999     18/02/1986     0.0
#
# [135493 rows x 38 columns]

# %%
fig = plt.figure(figsize=(12,12))
g = sns.heatmap(full_train_df.select_dtypes("number").corr(), annot=True, fmt=".1f", square=True, cbar=False)
g.set_xticklabels(labels=g.get_xmajorticklabels(),fontsize=5)
g.set_yticklabels(labels=g.get_ymajorticklabels(),fontsize=5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Preparing for training

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold

## models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
random_state = 42
skf = StratifiedKFold(n_splits=5, shuffle=True)

# %%
X = full_train_df.drop(["target", "creation_date"], axis=1)
y = full_train_df["target"]

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# ##### Logistic Regression

# %%
params = {
    "C": [0.5,1,1.5]
}

grid_lr = GridSearchCV(LogisticRegression(max_iter=10000), params, scoring="roc_auc", cv=skf, verbose=10)
grid_lr.fit(X,y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5; 1/3] START C=0.5.......................................................
# [CV 1/5; 1/3] END ........................C=0.5;, score=0.757 total time=   4.1s
# [CV 2/5; 1/3] START C=0.5.......................................................
# [CV 2/5; 1/3] END ........................C=0.5;, score=0.759 total time=   6.3s
# [CV 3/5; 1/3] START C=0.5.......................................................
# [CV 3/5; 1/3] END ........................C=0.5;, score=0.759 total time=   5.3s
# [CV 4/5; 1/3] START C=0.5.......................................................
# [CV 4/5; 1/3] END ........................C=0.5;, score=0.765 total time=   3.8s
# [CV 5/5; 1/3] START C=0.5.......................................................
# [CV 5/5; 1/3] END ........................C=0.5;, score=0.755 total time=   4.7s
# [CV 1/5; 2/3] START C=1.........................................................
# [CV 1/5; 2/3] END ..........................C=1;, score=0.757 total time=   4.8s
# [CV 2/5; 2/3] START C=1.........................................................
# [CV 2/5; 2/3] END ..........................C=1;, score=0.759 total time=   6.3s
# [CV 3/5; 2/3] START C=1.........................................................
# [CV 3/5; 2/3] END ..........................C=1;, score=0.759 total time=   5.8s
# [CV 4/5; 2/3] START C=1.........................................................
# [CV 4/5; 2/3] END ..........................C=1;, score=0.765 total time=   5.1s
# [CV 5/5; 2/3] START C=1.........................................................
# [CV 5/5; 2/3] END ..........................C=1;, score=0.755 total time=   5.6s
# [CV 1/5; 3/3] START C=1.5.......................................................
# [CV 1/5; 3/3] END ........................C=1.5;, score=0.757 total time=   7.8s
# [CV 2/5; 3/3] START C=1.5.......................................................
# [CV 2/5; 3/3] END ........................C=1.5;, score=0.759 total time=   9.1s
# [CV 3/5; 3/3] START C=1.5.......................................................
# [CV 3/5; 3/3] END ........................C=1.5;, score=0.759 total time=   6.0s
# [CV 4/5; 3/3] START C=1.5.......................................................
# [CV 4/5; 3/3] END ........................C=1.5;, score=0.765 total time=   6.8s
# [CV 5/5; 3/3] START C=1.5.......................................................
# [CV 5/5; 3/3] END ........................C=1.5;, score=0.754 total time=   7.2s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=True),
#              estimator=LogisticRegression(max_iter=10000),
#              param_grid={'C': [0.5, 1, 1.5]}, scoring='roc_auc', verbose=10)

# %%
print(grid_lr.best_score_)
print(grid_lr.best_params_)
# Out:
# 0.7590944386464777
# {'C': 0.5}

# %% [markdown]
# ### Predicting for Submission

# %%
full_test_df = process_data(client_test, invoice_test, num_cols)

# %%
X_sub = scaler.transform(full_test_df)

# %%
preds = grid_lr.predict_proba(X_sub)[:,1]

# %%
preds
# Out:
# array([0.04959434, 0.09065027, 0.11106597, ..., 0.23325567, 0.00337634,
#        0.0944703 ])

# %% [markdown]
# ### Submitting

# %%
sample_sub = pd.read_csv("x__data/SampleSubmission.csv")
sample_sub
# Out:
#               client_id    target
# 0         test_Client_0  0.957281
# 1         test_Client_1  0.996425
# 2        test_Client_10  0.612359
# 3       test_Client_100  0.776933
# 4      test_Client_1000  0.571046
# ...                 ...       ...
# 58064  test_Client_9995  0.882548
# 58065  test_Client_9996  0.715918
# 58066  test_Client_9997  0.285178
# 58067  test_Client_9998  0.154661
# 58068  test_Client_9999  0.556017
#
# [58069 rows x 2 columns]

# %%
test_ids = full_test_df.index

# %%
# submission = sample_sub.copy()
# submission["target"]= preds
submission = pd.DataFrame({"client_id": test_ids, "target": preds})

# %%
submission
# Out:
#               client_id    target
# 0         test_Client_0  0.049594
# 1         test_Client_1  0.090650
# 2        test_Client_10  0.111066
# 3       test_Client_100  0.021958
# 4      test_Client_1000  0.104652
# ...                 ...       ...
# 58064  test_Client_9995  0.012117
# 58065  test_Client_9996  0.042593
# 58066  test_Client_9997  0.233256
# 58067  test_Client_9998  0.003376
# 58068  test_Client_9999  0.094470
#
# [58069 rows x 2 columns]
